# %%
# !pip install -U sagemaker
# Out:
# Requirement already satisfied: sagemaker in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.109.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (21.3)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: importlib-metadata<5.0,>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (3.7.0)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.1.5)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: protobuf3-to-dict<1.0,>=0.1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.1.5)
# Requirement already satisfied: boto3<2.0,>=1.20.21 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.23.10)
# Requirement already satisfied: attrs<22,>=20.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (20.3.0)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.2.8)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.19.5)
# Requirement already satisfied: protobuf<4.0,>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (3.15.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0,>=1.20.21->sagemaker) (0.10.0)
# Requirement already satisfied: botocore<1.27.0,>=1.26.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0,>=1.20.21->sagemaker) (1.26.10)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0,>=1.20.21->sagemaker) (0.5.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata<5.0,>=1.4.0->sagemaker) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata<5.0,>=1.4.0->sagemaker) (4.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging>=20.0->sagemaker) (2.4.7)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from protobuf<4.0,>=3.1->sagemaker) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas->sagemaker) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas->sagemaker) (2021.1)
# Requirement already satisfied: pox>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.3.0)
# Requirement already satisfied: dill>=0.3.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.3.4)
# Requirement already satisfied: ppft>=1.6.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (1.6.6.4)
# Requirement already satisfied: multiprocess>=0.70.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.70.12.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.27.0,>=1.26.10->boto3<2.0,>=1.20.21->sagemaker) (1.26.8)

# %%
from sagemaker import get_execution_role
from sagemaker.pytorch.estimator import PyTorch

role = get_execution_role()
role
# Out:
# 'arn:aws:iam::666048841835:role/prod-bi-analy-ml-pltf-sagemaker-exec-role'

# %%
# GCN_3
# hyperparameters = dict(
#     feature_size=26,
#     out_embed_s=32,
#     num_node_types=8,
#     num_train=375,
#     num_eval=225,
#     batch_s=125,
#     mini_batch_s=125,
#     hidden_channels=16,
#     save_model_freq=2,
#     lr=0.005,
#     train_iter_n=200,
#     model_version=3,
#     ignore_weight=False,
#     split_data=False,
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_sum'
# )
# hyperparameters

# %%
# # GCN_7 StreamSpot
# hyperparameters = dict(
#     feature_size=26,
#     out_embed_s=26,
#     num_hidden_conv_layers=2,
#     num_node_types=8,
#     source_types='0,1',
#     num_train=375,
#     num_eval=225,
#     batch_s=25,
#     mini_batch_s=25,
#     input_type='batch',
#     hidden_channels=26,
#     save_model_freq=2,
#     lr=0.001,
#     train_iter_n=100,
#     model_version=7,
#     ignore_weight=True,
#     split_data=False,
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn_v7_no_weight_h2'
# )
# hyperparameters

# %%
# GCN_3
# hyperparameters = dict(
#     feature_size=26,
#     out_embed_s=26,
#     num_node_types=8,
#     num_train=375,
#     num_eval=225,
#     batch_s=125,
#     mini_batch_s=125,
#     hidden_channels=26,
#     save_model_freq=2,
#     lr=0.005,
#     train_iter_n=200,
#     model_version=3,
#     ignore_weight=False,
#     split_data=False,
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn3'
# )
# hyperparameters

# %%
# GCN_3_1
# hyperparameters = dict(
#     feature_size=26,
#     out_embed_s=26,
#     num_node_types=8,
#     num_train=375,
#     num_eval=225,
#     batch_s=125,
#     mini_batch_s=125,
#     hidden_channels=26,
#     save_model_freq=2,
#     lr=0.005,
#     seed=10,
#     train_iter_n=200,
#     model_version=3,
#     model_sub_version=1,
#     ignore_weight=False,
#     split_data=False,
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn3_1'
# )
# hyperparameters

# %%
# GCN_3_1 Streamspot

# python main.py \
# --sagemaker False \
# --num_node_types 8 \
# --num_train 375 \
# --batch_s 125 \
# --mini_batch_s 125 \
# --num_eval 225 \
# --hidden_channels 26 \
# --seed 10 \
# --s3_stage False \
# --split_data False \
# --ignore_weight False \
# --test_set True \
# --save_model_freq 2 \
# --lr 0.005 \
# --train_iter_n 200 \
# --model_version 3 \
# --model_sub_version 1 \
# --dataset_id 0 \
# --feature_size 26 \
# --out_embed_s 26 \
# --model_path ../model_save_HetGCN_streamspot_weight \
# --data_path ../ProcessedData_streamspot

# %%
# # GCN_3_1 TraLog
# hyperparameters = dict(
#     feature_size=7,
#     out_embed_s=16,
#     hidden_channels=16,
#     num_node_types=8,
#     num_train=65000,
#     num_eval=30000,
#     batch_s=500,
#     mini_batch_s=500,
#     save_model_freq=2,
#     lr=0.001,
#     seed=10,
#     train_iter_n=200,
#     model_version=3,
#     model_sub_version=1,
#     ignore_weight=False,
#     split_data=False,
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn3_1'
# )
# hyperparameters

# %%
# # GCN_3 TraLog
# hyperparameters = dict(
#     feature_size=7,
#     out_embed_s=16,
#     hidden_channels=16,
#     num_node_types=8,
#     num_train=65000,
#     num_eval=30000,
#     batch_s=500,
#     mini_batch_s=500,
#     save_model_freq=2,
#     lr=0.001,
#     seed=10,
#     train_iter_n=200,
#     model_version=3,
#     model_sub_version=0,
#     ignore_weight=False,
#     split_data=True,
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn3'
# )
# hyperparameters

# %%
# GCN_4 TraLog
# hyperparameters = dict(
#     feature_size=7,
#     out_embed_s=16,
#     hidden_channels=16,
#     num_node_types=8,
#     num_train=65000,
#     num_eval=30000,
#     batch_s=500,
#     mini_batch_s=500,
#     save_model_freq=2,
#     lr=0.001,
#     seed=10,
#     train_iter_n=200,
#     model_version=4,
#     model_sub_version=0,
#     source_types='0,1,2,3,4,5,6,7',
#     ignore_weight=False,
#     split_data=True,
#     input_type='batch',
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn4'
# )
# hyperparameters

# %%
# # # GCN_8 TraLog
# hyperparameters = dict(
#     feature_size=7,
#     out_embed_s=300,
#     hidden_channels=300,
#     num_hidden_conv_layers=3,
#     num_node_types=8,
#     num_edge_types=4,
#     num_train=65000,
#     sampling_size=3200,
#     eval_size=10000,
#     batch_s=8,
#     mini_batch_s=8,
#     save_model_freq=2,
#     lr=0.0001,
#     train_iter_n=400,
#     model_version=8,
#     model_sub_version=0,  # Model Sub Version
#     source_types='0,1,2,3,4,5,6,7',
#     ignore_weight=True,
#     split_data=False,
#     input_type='batch',
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn8_h3_noweight'
# )
# hyperparameters

# %%
# # # GCN_10 TraLog
# hyperparameters = dict(
#     feature_size=7,
#     out_embed_s=300,
#     hidden_channels=300,
#     num_hidden_conv_layers=1,
#     num_node_types=8,
#     num_edge_types=4,
#     num_train=65000,
#     sampling_size=3200,
#     eval_size=10000,
#     batch_s=8,
#     mini_batch_s=8,
#     save_model_freq=2,
#     lr=0.0001,
#     train_iter_n=400,
#     trainer_version=1,
#     model_version=10,
#     model_sub_version=0,  # Model Sub Version
#     source_types='0,1,2,3,4,5,6,7',
#     ignore_weight=True,
#     split_data=False,
#     input_type='batch',
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn10'
# )
# hyperparameters

# %%
# # GCN_7 TraLog
# hyperparameters = dict(
#     feature_size=7,
#     out_embed_s=300,
#     hidden_channels=300,
#     num_hidden_conv_layers=2,
#     num_node_types=8,
#     num_train=65000,
#     sampling_size=3200,
#     eval_size=10000,
#     batch_s=64,
#     mini_batch_s=64,
#     save_model_freq=2,
#     lr=0.0001,
#     train_iter_n=1000,
#     model_version=7,
#     model_sub_version=0,  # Model Sub Version
#     source_types='0,1,2,3,4,5,6,7',
#     ignore_weight=False,
#     split_data=False,
#     input_type='batch',
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn70_h2_simple_weight_batch64'
# )
# hyperparameters

# %%
# # GCN_9 TraLog
# hyperparameters = dict(
#     feature_size=7,
#     out_embed_s=300,
#     hidden_channels=300,
#     num_edge_types=4,
#     num_train=65000,
#     sampling_size=3200,
#     eval_size=10000,
#     batch_s=32,
#     mini_batch_s=32,
#     save_model_freq=2,
#     lr=0.0001,
#     train_iter_n=200,
#     model_version=9,
#     model_sub_version=0,  # Model Sub Version
#     ignore_weight=True,
#     split_data=False,
#     input_type='batch',
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn9'
# )
# hyperparameters

# %%
# GCN_9 StreamSpot
hyperparameters = dict(
    feature_size=26,
    out_embed_s=32,
    hidden_channels=32,
    num_train=375,
    sampling_size=375,
    eval_size=375,
    batch_s=25,
    mini_batch_s=25,
    save_model_freq=2,
    lr=0.0001,
    train_iter_n=300,
    model_version=9,
    model_sub_version=0,  # Model Sub Version
    ignore_weight=False,
    split_data=False,
    input_type='batch',
    s3_stage=True,
    s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9'
)
hyperparameters
# Out:
# {'feature_size': 26,
#  'out_embed_s': 32,
#  'hidden_channels': 32,
#  'num_train': 375,
#  'sampling_size': 375,
#  'eval_size': 375,
#  'batch_s': 25,
#  'mini_batch_s': 25,
#  'save_model_freq': 2,
#  'lr': 0.0001,
#  'train_iter_n': 300,
#  'model_version': 9,
#  'model_sub_version': 0,
#  'ignore_weight': False,
#  'split_data': False,
#  'input_type': 'batch',
#  's3_stage': True,
#  's3_prefix': 'application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9'}

# %%
# GCN_SUM
# hyperparameters = dict(
#     feature_size=26,
#     out_embed_s=26,
#     num_node_types=8,
#     num_train=375,
#     num_eval=225,
#     batch_s=125,
#     mini_batch_s=125,
#     hidden_channels=26,
#     save_model_freq=2,
#     lr=0.005,
#     train_iter_n=200,
#     model_version=3,
#     ignore_weight=False,
#     split_data=False,
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_combine_g_before_concat'
# )
# hyperparameters

# %%
estimator = PyTorch(
    source_dir='./code_gcn/',
    entry_point='main.py',
#     framework_version='1.9.1',
#     py_version='py38',
    image_uri='666048841835.dkr.ecr.ap-southeast-2.amazonaws.com/pytorch-hetgcn:latest',
    instance_type='ml.g4dn.2xlarge',
    instance_count=1,
    volume_size=150,
    max_run=24*60*60*2,
    role=role,
    base_job_name='HetGNN',
    hyperparameters=hyperparameters,
    metric_definitions=[
        {
            "Name": "Loss",
            "Regex": "Epoch Loss: (.*?);",
        },
        {
            "Name": "Batch Loss",
            "Regex": "Batch Loss: (.*?);",
        },
        {
            "Name": "Epoch Time",
            "Regex": "Epoch Time: (.*?);",
        },
        {
            "Name": "Batch Time",
            "Regex": "Batch Time: (.*?);",
        },
        {
            "Name": "AUC",
            "Regex": "AUC:(.*?);",
        },
        {
            "Name": "AP",
            "Regex": "Avg Precision:(.*?);"
        }
    ]
)

# %%
estimator.fit(
    {
#         'train': 's3://prod-tpgt-knowledge-lake-sandpit-v1/application/anomaly_detection/deeptralog/HetGNN/ProcessedData_synth/'
#         'train': 's3://prod-tpgt-knowledge-lake-sandpit-v1/application/anomaly_detection/deeptralog/HetGNN/ProcessedData_clean/'
#         'train': 's3://prod-tpgt-knowledge-lake-sandpit-v1/application/anomaly_detection/deeptralog/HetGNN/ProcessedData_HetGCN/'
        'train': 's3://prod-tpgt-knowledge-lake-sandpit-v1/application/anomaly_detection/deeptralog/HetGNN/ProcessedData_streamspot/'
    }
)
# Out:
# 2022-09-25 06:50:47 Starting - Starting the training job...
# 2022-09-25 06:51:11 Starting - Preparing the instances for trainingProfilerReport-1664088647: InProgress
# ......
# 2022-09-25 06:52:13 Downloading - Downloading input data...
# 2022-09-25 06:52:38 Training - Downloading the training image.......................bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-09-25 06:56:28,297 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-09-25 06:56:28,324 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-09-25 06:56:28,329 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-09-25 06:56:28,913 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1"
#     ],
#     "current_instance_type": "ml.g4dn.2xlarge",
#     "distribution_hosts": [],
#     "distribution_instance_groups": [],
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_s": 25,
#         "eval_size": 375,
#         "feature_size": 26,
#         "hidden_channels": 32,
#         "ignore_weight": false,
#         "input_type": "batch",
#         "lr": 0.0001,
#         "mini_batch_s": 25,
#         "model_sub_version": 0,
#         "model_version": 9,
#         "num_train": 375,
#         "out_embed_s": 32,
#         "s3_prefix": "application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9",
#         "s3_stage": true,
#         "sampling_size": 375,
#         "save_model_freq": 2,
#         "split_data": false,
#         "train_iter_n": 300
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.g4dn.2xlarge",
#             "hosts": [
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "job_name": "HetGNN-2022-09-25-06-50-46-733",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-southeast-2-666048841835/HetGNN-2022-09-25-06-50-46-733/source/sourcedir.tar.gz",
#     "module_name": "main",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.g4dn.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.g4dn.2xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "main.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_s":25,"eval_size":375,"feature_size":26,"hidden_channels":32,"ignore_weight":false,"input_type":"batch","lr":0.0001,"mini_batch_s":25,"model_sub_version":0,"model_version":9,"num_train":375,"out_embed_s":32,"s3_prefix":"application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9","s3_stage":true,"sampling_size":375,"save_model_freq":2,"split_data":false,"train_iter_n":300}
# SM_USER_ENTRY_POINT=main.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.g4dn.2xlarge
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.2xlarge"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# SM_IS_HETERO=false
# SM_MODULE_NAME=main
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-southeast-2-666048841835/HetGNN-2022-09-25-06-50-46-733/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1"],"current_instance_type":"ml.g4dn.2xlarge","distribution_hosts":[],"distribution_instance_groups":[],"framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_s":25,"eval_size":375,"feature_size":26,"hidden_channels":32,"ignore_weight":false,"input_type":"batch","lr":0.0001,"mini_batch_s":25,"model_sub_version":0,"model_version":9,"num_train":375,"out_embed_s":32,"s3_prefix":"application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9","s3_stage":true,"sampling_size":375,"save_model_freq":2,"split_data":false,"train_iter_n":300},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.2xlarge"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"job_name":"HetGNN-2022-09-25-06-50-46-733","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-southeast-2-666048841835/HetGNN-2022-09-25-06-50-46-733/source/sourcedir.tar.gz","module_name":"main","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"main.py"}
# SM_USER_ARGS=["--batch_s","25","--eval_size","375","--feature_size","26","--hidden_channels","32","--ignore_weight","False","--input_type","batch","--lr","0.0001","--mini_batch_s","25","--model_sub_version","0","--model_version","9","--num_train","375","--out_embed_s","32","--s3_prefix","application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9","--s3_stage","True","--sampling_size","375","--save_model_freq","2","--split_data","False","--train_iter_n","300"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_BATCH_S=25
# SM_HP_EVAL_SIZE=375
# SM_HP_FEATURE_SIZE=26
# SM_HP_HIDDEN_CHANNELS=32
# SM_HP_IGNORE_WEIGHT=false
# SM_HP_INPUT_TYPE=batch
# SM_HP_LR=0.0001
# SM_HP_MINI_BATCH_S=25
# SM_HP_MODEL_SUB_VERSION=0
# SM_HP_MODEL_VERSION=9
# SM_HP_NUM_TRAIN=375
# SM_HP_OUT_EMBED_S=32
# SM_HP_S3_PREFIX=application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9
# SM_HP_S3_STAGE=true
# SM_HP_SAMPLING_SIZE=375
# SM_HP_SAVE_MODEL_FREQ=2
# SM_HP_SPLIT_DATA=false
# SM_HP_TRAIN_ITER_N=300
# PYTHONPATH=/opt/ml/code:/opt/conda/lib/python3.8/site-packages/smdistributed/dataparallel/lib:/opt/conda/bin:/opt/conda/lib/python38.zip:/opt/conda/lib/python3.8:/opt/conda/lib/python3.8/lib-dynload:/opt/conda/lib/python3.8/site-packages:/opt/conda/lib/python3.8/site-packages/smdebug-1.0.16b20220819-py3.8.egg:/opt/conda/lib/python3.8/site-packages/pyinstrument-3.4.2-py3.8.egg:/opt/conda/lib/python3.8/site-packages/pyinstrument_cext-0.2.4-py3.8-linux-x86_64.egg
# Invoking script with the following command:
# /opt/conda/bin/python3.8 main.py --batch_s 25 --eval_size 375 --feature_size 26 --hidden_channels 32 --ignore_weight False --input_type batch --lr 0.0001 --mini_batch_s 25 --model_sub_version 0 --model_version 9 --num_train 375 --out_embed_s 32 --s3_prefix application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9 --s3_stage True --sampling_size 375 --save_model_freq 2 --split_data False --train_iter_n 300
# {'batch_s': 25, 'eval_size': 375, 'feature_size': 26, 'hidden_channels': 32, 'ignore_weight': False, 'input_type': 'batch', 'lr': 0.0001, 'mini_batch_s': 25, 'model_sub_version': 0, 'model_version': 9, 'num_train': 375, 'out_embed_s': 32, 's3_prefix': 'application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9', 's3_stage': True, 'sampling_size': 375, 'save_model_freq': 2, 'split_data': False, 'train_iter_n': 300, 'model_path': '/opt/ml/model', 'data_path': '/opt/ml/input/data/train', 'num_eval': None, 'num_node_types': 8, 'num_edge_types': 1, 'source_types': None, 'num_hidden_conv_layers': 1, 'seed': 32, 'trainer_version': 0, 'dataset_id': 0, 'fix_center': True, 'test_set': True, 'sagemaker': True, 'unzip': True, 's3_bucket': 'prod-tpgt-knowledge-lake-sandpit-v1'}
# Device: cuda
# reading node features..
#
# 2022-09-25 06:56:32 Training - Training image download completed. Training in progress.reading edge index..
# Found Edge Weights.
# read node types ..
# node types txt: 600
# done
# HetGCN_9(
#   (in_fcs): ModuleList(
#     (0): Linear(in_features=26, out_features=32, bias=True)
#   )
#   (out_fcs): ModuleList(
#     (0): Linear(in_features=26, out_features=32, bias=True)
#   )
#   (reset_gate): Sequential(
#     (0): Linear(in_features=64, out_features=32, bias=True)
#     (1): Sigmoid()
#   )
#   (update_gate): Sequential(
#     (0): Linear(in_features=64, out_features=32, bias=True)
#     (1): Sigmoid()
#   )
#   (tansform): Sequential(
#     (0): Linear(in_features=96, out_features=32, bias=True)
#     (1): Tanh()
#   )
#   (out): Sequential(
#     (0): Linear(in_features=32, out_features=32, bias=True)
#     (1): Tanh()
#   )
#   (relu): Tanh()
#   (sigmoid): Sigmoid()
# )
# model training ...
# Read Existing Split Train/Eval/Test.
# iteration 0 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# [2022-09-25 06:56:53.906 algo-1:28 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# /opt/conda/lib/python3.8/site-packages/smdebug-1.0.16b20220819-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /opt/conda/lib/python3.8/site-packages/smdebug-1.0.16b20220819-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [2022-09-25 06:56:54.091 algo-1:28 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2022-09-25 06:56:54.092 algo-1:28 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-09-25 06:56:54.092 algo-1:28 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-09-25 06:56:54.093 algo-1:28 INFO hook.py:254] Saving to /opt/ml/output/tensors
# [2022-09-25 06:56:54.093 algo-1:28 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-09-25 06:56:54.093 algo-1:28 INFO hook.py:560] name:in_fcs.0.weight count_params:832
# [2022-09-25 06:56:54.094 algo-1:28 INFO hook.py:560] name:in_fcs.0.bias count_params:32
# [2022-09-25 06:56:54.094 algo-1:28 INFO hook.py:560] name:out_fcs.0.weight count_params:832
# [2022-09-25 06:56:54.094 algo-1:28 INFO hook.py:560] name:out_fcs.0.bias count_params:32
# [2022-09-25 06:56:54.094 algo-1:28 INFO hook.py:560] name:reset_gate.0.weight count_params:2048
# [2022-09-25 06:56:54.094 algo-1:28 INFO hook.py:560] name:reset_gate.0.bias count_params:32
# [2022-09-25 06:56:54.094 algo-1:28 INFO hook.py:560] name:update_gate.0.weight count_params:2048
# [2022-09-25 06:56:54.094 algo-1:28 INFO hook.py:560] name:update_gate.0.bias count_params:32
# [2022-09-25 06:56:54.094 algo-1:28 INFO hook.py:560] name:tansform.0.weight count_params:3072
# [2022-09-25 06:56:54.094 algo-1:28 INFO hook.py:560] name:tansform.0.bias count_params:32
# [2022-09-25 06:56:54.094 algo-1:28 INFO hook.py:560] name:out.0.weight count_params:1024
# [2022-09-25 06:56:54.094 algo-1:28 INFO hook.py:560] name:out.0.bias count_params:32
# [2022-09-25 06:56:54.094 algo-1:28 INFO hook.py:562] Total Trainable Params: 10048
# [2022-09-25 06:56:54.094 algo-1:28 INFO hook.py:421] Monitoring the collections: losses
# [2022-09-25 06:56:54.094 algo-1:28 INFO hook.py:485] Hook is writing from the hook with pid: 28
# Set initial center ..
# Batch Loss: 279239.40625; Batch Time: 1.804109811782837s;
# 1it [00:01,  1.80s/it]
# Batch Loss: 115574.59375; Batch Time: 0.7617282867431641s;
# 2it [00:02,  1.19s/it]
# Batch Loss: 301047.75; Batch Time: 0.84629225730896s;
# 3it [00:03,  1.03s/it]
# Batch Loss: 132353.796875; Batch Time: 0.7342102527618408s;
# 4it [00:04,  1.09it/s]
# Batch Loss: 199650.390625; Batch Time: 0.7475149631500244s;
# 5it [00:04,  1.17it/s]
# Batch Loss: 254647.796875; Batch Time: 0.7638630867004395s;
# 6it [00:05,  1.21it/s]
# Batch Loss: 266634.5; Batch Time: 0.7028427124023438s;
# 7it [00:06,  1.27it/s]
# Batch Loss: 236907.921875; Batch Time: 0.7243518829345703s;
# 8it [00:07,  1.31it/s]
# Batch Loss: 334753.28125; Batch Time: 0.7137093544006348s;
# 9it [00:07,  1.33it/s]
# Batch Loss: 282745.40625; Batch Time: 0.8355252742767334s;
# 10it [00:08,  1.29it/s]
# Batch Loss: 191201.59375; Batch Time: 0.7911932468414307s;
# 11it [00:09,  1.28it/s]
# Batch Loss: 244505.828125; Batch Time: 0.7125942707061768s;
# 12it [00:10,  1.32it/s]
# Batch Loss: 196502.234375; Batch Time: 0.781700611114502s;
# 13it [00:10,  1.30it/s]
# Batch Loss: 221997.71875; Batch Time: 0.8158044815063477s;
# 14it [00:11,  1.28it/s]
# Batch Loss: 252508.15625; Batch Time: 0.7683548927307129s;
# 15it [00:12,  1.29it/s]
# 15it [00:12,  1.20it/s]
# Epoch Loss: 234018.025; Epoch Time: 12.511260271072388s;
# Evaluating Model ..
# AUC:0.6107313149882231; Avg Precision:0.46412877382235784;
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_SVDD_Center.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/train_loss.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/eval_metrics.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_0.pt...
# iteration 0 finish.
# iteration 1 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 131874.09375; Batch Time: 0.79142165184021s;
# 1it [00:00,  1.26it/s]
# Batch Loss: 295448.90625; Batch Time: 0.7564125061035156s;
# 2it [00:01,  1.30it/s]
# Batch Loss: 208116.390625; Batch Time: 0.7380633354187012s;
# 3it [00:02,  1.32it/s]
# Batch Loss: 135945.453125; Batch Time: 0.7285614013671875s;
# 4it [00:03,  1.34it/s]
# Batch Loss: 101344.28125; Batch Time: 0.7100582122802734s;
# 5it [00:03,  1.36it/s]
# Batch Loss: 242553.859375; Batch Time: 0.6902320384979248s;
# 6it [00:04,  1.39it/s]
# Batch Loss: 134069.625; Batch Time: 0.7539498805999756s;
# 7it [00:05,  1.37it/s]
# Batch Loss: 122956.6796875; Batch Time: 0.7332184314727783s;
# 8it [00:05,  1.37it/s]
# Batch Loss: 197862.28125; Batch Time: 0.7411818504333496s;
# 9it [00:06,  1.36it/s]
# Batch Loss: 386786.5625; Batch Time: 0.7272164821624756s;
# 10it [00:07,  1.37it/s]
# Batch Loss: 222803.8125; Batch Time: 0.6920731067657471s;
# 11it [00:08,  1.39it/s]
# Batch Loss: 247692.359375; Batch Time: 0.7276275157928467s;
# 12it [00:08,  1.38it/s]
# Batch Loss: 199377.859375; Batch Time: 0.7376413345336914s;
# 13it [00:09,  1.38it/s]
# Batch Loss: 138665.484375; Batch Time: 0.7212069034576416s;
# 14it [00:10,  1.38it/s]
# Batch Loss: 94687.40625; Batch Time: 0.7426538467407227s;
# 15it [00:10,  1.37it/s]
# 15it [00:10,  1.36it/s]
# Epoch Loss: 190679.00364583332; Epoch Time: 10.995822668075562s;
# iteration 1 finish.
# iteration 2 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 54969.64453125; Batch Time: 0.7816128730773926s;
# 1it [00:00,  1.28it/s]
# Batch Loss: 248648.96875; Batch Time: 0.7111694812774658s;
# 2it [00:01,  1.35it/s]
# Batch Loss: 298330.34375; Batch Time: 0.7130117416381836s;
# 3it [00:02,  1.37it/s]
# Batch Loss: 213005.828125; Batch Time: 0.7501554489135742s;
# 4it [00:02,  1.36it/s]
# Batch Loss: 290500.15625; Batch Time: 0.8429186344146729s;
# 5it [00:03,  1.29it/s]
# Batch Loss: 218911.671875; Batch Time: 0.7649455070495605s;
# 6it [00:04,  1.30it/s]
# Batch Loss: 131654.421875; Batch Time: 0.7340793609619141s;
# 7it [00:05,  1.32it/s]
# Batch Loss: 166887.640625; Batch Time: 0.7572755813598633s;
# 8it [00:06,  1.32it/s]
# Batch Loss: 255425.78125; Batch Time: 0.7433760166168213s;
# 9it [00:06,  1.33it/s]
# Batch Loss: 206049.9375; Batch Time: 0.7556643486022949s;
# 10it [00:07,  1.33it/s]
# Batch Loss: 170377.734375; Batch Time: 0.6996583938598633s;
# 11it [00:08,  1.36it/s]
# Batch Loss: 178631.5625; Batch Time: 0.6836967468261719s;
# 12it [00:08,  1.39it/s]
# Batch Loss: 242746.1875; Batch Time: 0.6918535232543945s;
# 13it [00:09,  1.40it/s]
# Batch Loss: 161155.703125; Batch Time: 0.7076156139373779s;
# 14it [00:10,  1.41it/s]
# Batch Loss: 267979.125; Batch Time: 0.7462544441223145s;
# 15it [00:11,  1.39it/s]
# 15it [00:11,  1.35it/s]
# Epoch Loss: 207018.31380208334; Epoch Time: 11.08726978302002s;
# Evaluating Model ..
# AUC:0.6585977103149742; Avg Precision:0.5149711416402724;
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_SVDD_Center.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/train_loss.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/eval_metrics.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_0.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_2.pt...
# iteration 2 finish.
# iteration 3 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 254087.609375; Batch Time: 0.7845413684844971s;
# 1it [00:00,  1.27it/s]
# Batch Loss: 208350.203125; Batch Time: 0.7401156425476074s;
# 2it [00:01,  1.32it/s]
# Batch Loss: 384176.5625; Batch Time: 0.6936736106872559s;
# 3it [00:02,  1.37it/s]
# Batch Loss: 205653.0; Batch Time: 0.7440392971038818s;
# 4it [00:02,  1.36it/s]
# Batch Loss: 335275.8125; Batch Time: 0.694988489151001s;
# 5it [00:03,  1.39it/s]
# Batch Loss: 213729.75; Batch Time: 0.7115423679351807s;
# 6it [00:04,  1.39it/s]
# Batch Loss: 65206.8828125; Batch Time: 0.7675468921661377s;
# 7it [00:05,  1.36it/s]
# Batch Loss: 231878.921875; Batch Time: 0.7064285278320312s;
# 8it [00:05,  1.38it/s]
# Batch Loss: 346731.78125; Batch Time: 0.7548468112945557s;
# 9it [00:06,  1.36it/s]
# Batch Loss: 307002.1875; Batch Time: 0.7493045330047607s;
# 10it [00:07,  1.35it/s]
# Batch Loss: 101957.1015625; Batch Time: 0.7252931594848633s;
# 11it [00:08,  1.36it/s]
# Batch Loss: 376185.3125; Batch Time: 0.7625713348388672s;
# 12it [00:08,  1.35it/s]
# Batch Loss: 279087.0; Batch Time: 0.7168319225311279s;
# 13it [00:09,  1.36it/s]
# Batch Loss: 280958.40625; Batch Time: 0.7724571228027344s;
# 14it [00:10,  1.34it/s]
# Batch Loss: 209993.140625; Batch Time: 0.7627201080322266s;
# 15it [00:11,  1.33it/s]
# 15it [00:11,  1.35it/s]
# Epoch Loss: 253351.578125; Epoch Time: 11.091176271438599s;
# iteration 3 finish.
# iteration 4 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 257506.546875; Batch Time: 0.7378449440002441s;
# 1it [00:00,  1.36it/s]
# Batch Loss: 185405.390625; Batch Time: 0.7415471076965332s;
# 2it [00:01,  1.35it/s]
# Batch Loss: 218281.46875; Batch Time: 0.739203929901123s;
# 3it [00:02,  1.35it/s]
# Batch Loss: 144589.859375; Batch Time: 0.7832283973693848s;
# 4it [00:03,  1.32it/s]
# Batch Loss: 350915.6875; Batch Time: 0.7687139511108398s;
# 5it [00:03,  1.31it/s]
# Batch Loss: 136085.859375; Batch Time: 0.815070629119873s;
# 6it [00:04,  1.28it/s]
# Batch Loss: 212771.109375; Batch Time: 0.8228781223297119s;
# 7it [00:05,  1.26it/s]
# Batch Loss: 184302.875; Batch Time: 0.7499971389770508s;
# 8it [00:06,  1.28it/s]
# Batch Loss: 121943.2578125; Batch Time: 0.7240438461303711s;
# 9it [00:06,  1.31it/s]
# Batch Loss: 240631.078125; Batch Time: 0.710695743560791s;
# 10it [00:07,  1.34it/s]
# Batch Loss: 141407.5625; Batch Time: 0.7012293338775635s;
# 11it [00:08,  1.36it/s]
# Batch Loss: 184103.109375; Batch Time: 0.7604591846466064s;
# 12it [00:09,  1.35it/s]
# Batch Loss: 271530.96875; Batch Time: 0.749016284942627s;
# 13it [00:09,  1.34it/s]
# Batch Loss: 282964.75; Batch Time: 0.7820830345153809s;
# 14it [00:10,  1.32it/s]
# Batch Loss: 217441.890625; Batch Time: 0.7150988578796387s;
# 15it [00:11,  1.35it/s]
# 15it [00:11,  1.33it/s]
# Epoch Loss: 209992.09427083333; Epoch Time: 11.305570840835571s;
# Evaluating Model ..
# AUC:0.6692060946271051; Avg Precision:0.5043650445546692;
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_SVDD_Center.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_4.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/train_loss.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/eval_metrics.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_0.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_2.pt...
# iteration 4 finish.
# iteration 5 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 254522.21875; Batch Time: 0.7427103519439697s;
# 1it [00:00,  1.35it/s]
# Batch Loss: 119950.7109375; Batch Time: 0.7495913505554199s;
# 2it [00:01,  1.34it/s]
# Batch Loss: 275086.6875; Batch Time: 0.7505583763122559s;
# 3it [00:02,  1.34it/s]
# Batch Loss: 135512.84375; Batch Time: 0.6942932605743408s;
# 4it [00:02,  1.37it/s]
# Batch Loss: 125302.296875; Batch Time: 0.7106080055236816s;
# 5it [00:03,  1.39it/s]
# Batch Loss: 202557.921875; Batch Time: 0.7497851848602295s;
# 6it [00:04,  1.37it/s]
# Batch Loss: 203365.03125; Batch Time: 0.7040848731994629s;
# 7it [00:05,  1.38it/s]
# Batch Loss: 243568.3125; Batch Time: 0.7196223735809326s;
# 8it [00:05,  1.39it/s]
# Batch Loss: 334476.9375; Batch Time: 0.6976566314697266s;
# 9it [00:06,  1.40it/s]
# Batch Loss: 292342.59375; Batch Time: 0.7070357799530029s;
# 10it [00:07,  1.40it/s]
# Batch Loss: 245161.59375; Batch Time: 0.7685976028442383s;
# 11it [00:07,  1.37it/s]
# Batch Loss: 197772.828125; Batch Time: 0.7714762687683105s;
# 12it [00:08,  1.35it/s]
# Batch Loss: 133074.859375; Batch Time: 0.7396514415740967s;
# 13it [00:09,  1.35it/s]
# Batch Loss: 214153.921875; Batch Time: 0.7554953098297119s;
# 14it [00:10,  1.34it/s]
# Batch Loss: 291740.25; Batch Time: 0.7111139297485352s;
# 15it [00:10,  1.36it/s]
# 15it [00:10,  1.37it/s]
# Epoch Loss: 217905.93385416668; Epoch Time: 10.976531267166138s;
# iteration 5 finish.
# iteration 6 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 126493.046875; Batch Time: 0.7439947128295898s;
# 1it [00:00,  1.34it/s]
# Batch Loss: 266080.65625; Batch Time: 0.7680926322937012s;
# 2it [00:01,  1.32it/s]
# Batch Loss: 200127.28125; Batch Time: 0.7053020000457764s;
# 3it [00:02,  1.36it/s]
# Batch Loss: 283295.5; Batch Time: 0.7162859439849854s;
# 4it [00:02,  1.38it/s]
# Batch Loss: 214161.015625; Batch Time: 0.7013733386993408s;
# 5it [00:03,  1.39it/s]
# Batch Loss: 270725.4375; Batch Time: 0.7113959789276123s;
# 6it [00:04,  1.40it/s]
# Batch Loss: 286490.25; Batch Time: 0.688784122467041s;
# 7it [00:05,  1.41it/s]
# Batch Loss: 291086.46875; Batch Time: 0.6864004135131836s;
# 8it [00:05,  1.43it/s]
# Batch Loss: 191430.3125; Batch Time: 0.7367098331451416s;
# 9it [00:06,  1.40it/s]
# Batch Loss: 205691.78125; Batch Time: 0.7690122127532959s;
# 10it [00:07,  1.37it/s]
# Batch Loss: 137541.984375; Batch Time: 0.7029407024383545s;
# 11it [00:07,  1.39it/s]
# Batch Loss: 140959.515625; Batch Time: 0.6925139427185059s;
# 12it [00:08,  1.40it/s]
# Batch Loss: 185662.390625; Batch Time: 0.6991517543792725s;
# 13it [00:09,  1.41it/s]
# Batch Loss: 264487.5625; Batch Time: 0.7342233657836914s;
# 14it [00:10,  1.40it/s]
# Batch Loss: 392629.0625; Batch Time: 0.7733776569366455s;
# 15it [00:10,  1.36it/s]
# 15it [00:10,  1.38it/s]
# Epoch Loss: 230457.484375; Epoch Time: 10.83345913887024s;
# Evaluating Model ..
# AUC:0.6358408097538532; Avg Precision:0.47326419017712346;
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_SVDD_Center.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_6.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_4.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/train_loss.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/eval_metrics.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_0.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_2.pt...
# iteration 6 finish.
# iteration 7 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 210319.390625; Batch Time: 0.760554313659668s;
# 1it [00:00,  1.31it/s]
# Batch Loss: 237988.171875; Batch Time: 0.7077407836914062s;
# 2it [00:01,  1.37it/s]
# Batch Loss: 282960.90625; Batch Time: 0.7485005855560303s;
# 3it [00:02,  1.35it/s]
# Batch Loss: 137447.609375; Batch Time: 0.7568981647491455s;
# 4it [00:02,  1.34it/s]
# Batch Loss: 276269.21875; Batch Time: 0.7138159275054932s;
# 5it [00:03,  1.36it/s]
# Batch Loss: 247717.46875; Batch Time: 0.693300724029541s;
# 6it [00:04,  1.39it/s]
# Batch Loss: 274748.4375; Batch Time: 0.7316617965698242s;
# 7it [00:05,  1.38it/s]
# Batch Loss: 205402.4375; Batch Time: 0.7176408767700195s;
# 8it [00:05,  1.38it/s]
# Batch Loss: 423423.84375; Batch Time: 0.7633552551269531s;
# 9it [00:06,  1.36it/s]
# Batch Loss: 257902.46875; Batch Time: 0.7763705253601074s;
# 10it [00:07,  1.34it/s]
# Batch Loss: 173398.21875; Batch Time: 0.8330538272857666s;
# 11it [00:08,  1.29it/s]
# Batch Loss: 228530.6875; Batch Time: 0.7694211006164551s;
# 12it [00:08,  1.29it/s]
# Batch Loss: 129517.734375; Batch Time: 0.7656934261322021s;
# 13it [00:09,  1.30it/s]
# Batch Loss: 240692.15625; Batch Time: 0.7431814670562744s;
# 14it [00:10,  1.31it/s]
# Batch Loss: 206079.359375; Batch Time: 0.7042906284332275s;
# 15it [00:11,  1.34it/s]
# 15it [00:11,  1.34it/s]
# Epoch Loss: 235493.20729166668; Epoch Time: 11.189511775970459s;
# iteration 7 finish.
# iteration 8 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 108091.859375; Batch Time: 0.7003536224365234s;
# 1it [00:00,  1.43it/s]
# Batch Loss: 338979.5; Batch Time: 0.7044439315795898s;
# 2it [00:01,  1.42it/s]
# Batch Loss: 315704.75; Batch Time: 0.7322511672973633s;
# 3it [00:02,  1.40it/s]
# Batch Loss: 162555.71875; Batch Time: 0.7391109466552734s;
# 4it [00:02,  1.38it/s]
# Batch Loss: 133227.015625; Batch Time: 0.7363815307617188s;
# 5it [00:03,  1.37it/s]
# Batch Loss: 284586.21875; Batch Time: 0.7290835380554199s;
# 6it [00:04,  1.37it/s]
# Batch Loss: 246626.453125; Batch Time: 0.6875901222229004s;
# 7it [00:05,  1.40it/s]
# Batch Loss: 227214.578125; Batch Time: 0.7251536846160889s;
# 8it [00:05,  1.39it/s]
# Batch Loss: 157661.609375; Batch Time: 0.7055971622467041s;
# 9it [00:06,  1.40it/s]
# Batch Loss: 257398.859375; Batch Time: 0.7032651901245117s;
# 10it [00:07,  1.41it/s]
# Batch Loss: 276475.125; Batch Time: 0.7235407829284668s;
# 11it [00:07,  1.40it/s]
# Batch Loss: 179599.671875; Batch Time: 0.739321231842041s;
# 12it [00:08,  1.38it/s]
# Batch Loss: 165311.0; Batch Time: 0.7465043067932129s;
# 13it [00:09,  1.37it/s]
# Batch Loss: 223494.65625; Batch Time: 0.7174806594848633s;
# 14it [00:10,  1.38it/s]
# Batch Loss: 187221.578125; Batch Time: 0.7528975009918213s;
# 15it [00:10,  1.36it/s]
# 15it [00:10,  1.38it/s]
# Epoch Loss: 217609.90625; Epoch Time: 10.846997737884521s;
# Evaluating Model ..
# AUC:0.5583028780264961; Avg Precision:0.45068845865361085;
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_SVDD_Center.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_6.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_4.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/train_loss.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_8.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/eval_metrics.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_0.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_2.pt...
# iteration 8 finish.
# iteration 9 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 315292.5; Batch Time: 0.7452170848846436s;
# 1it [00:00,  1.34it/s]
# Batch Loss: 173110.09375; Batch Time: 0.7244224548339844s;
# 2it [00:01,  1.36it/s]
# Batch Loss: 315337.78125; Batch Time: 0.7542388439178467s;
# 3it [00:02,  1.35it/s]
# Batch Loss: 285903.3125; Batch Time: 0.7001135349273682s;
# 4it [00:02,  1.38it/s]
# Batch Loss: 202630.390625; Batch Time: 0.7592658996582031s;
# 5it [00:03,  1.35it/s]
# Batch Loss: 322556.78125; Batch Time: 0.7448530197143555s;
# 6it [00:04,  1.35it/s]
# Batch Loss: 194655.109375; Batch Time: 0.7682385444641113s;
# 7it [00:05,  1.33it/s]
# Batch Loss: 197555.375; Batch Time: 0.7040307521820068s;
# 8it [00:05,  1.36it/s]
# Batch Loss: 148003.890625; Batch Time: 0.740847110748291s;
# 9it [00:06,  1.36it/s]
# Batch Loss: 259604.546875; Batch Time: 0.742426872253418s;
# 10it [00:07,  1.35it/s]
# Batch Loss: 168798.46875; Batch Time: 0.704190731048584s;
# 11it [00:08,  1.37it/s]
# Batch Loss: 210608.796875; Batch Time: 0.7293717861175537s;
# 12it [00:08,  1.37it/s]
# Batch Loss: 206359.921875; Batch Time: 0.7461612224578857s;
# 13it [00:09,  1.36it/s]
# Batch Loss: 164082.390625; Batch Time: 0.824878454208374s;
# 14it [00:10,  1.31it/s]
# Batch Loss: 199337.078125; Batch Time: 0.7483944892883301s;
# 15it [00:11,  1.32it/s]
# 15it [00:11,  1.35it/s]
# Epoch Loss: 224255.7625; Epoch Time: 11.14111852645874s;
# iteration 9 finish.
# iteration 10 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 101460.4140625; Batch Time: 0.7592899799346924s;
# 1it [00:00,  1.32it/s]
# Batch Loss: 274276.78125; Batch Time: 0.7442777156829834s;
# 2it [00:01,  1.33it/s]
# Batch Loss: 236891.796875; Batch Time: 0.7546582221984863s;
# 3it [00:02,  1.33it/s]
# Batch Loss: 121861.9765625; Batch Time: 0.7707016468048096s;
# 4it [00:03,  1.32it/s]
# Batch Loss: 370407.59375; Batch Time: 0.7378571033477783s;
# 5it [00:03,  1.33it/s]
# Batch Loss: 171551.203125; Batch Time: 0.7287232875823975s;
# 6it [00:04,  1.34it/s]
# Batch Loss: 106284.65625; Batch Time: 0.7175333499908447s;
# 7it [00:05,  1.36it/s]
# Batch Loss: 302939.03125; Batch Time: 0.7625906467437744s;
# 8it [00:05,  1.34it/s]
# Batch Loss: 231314.03125; Batch Time: 0.7643167972564697s;
# 9it [00:06,  1.33it/s]
# Batch Loss: 247535.234375; Batch Time: 0.7269959449768066s;
# 10it [00:07,  1.35it/s]
# Batch Loss: 158896.75; Batch Time: 0.7014210224151611s;
# 11it [00:08,  1.37it/s]
# Batch Loss: 261436.71875; Batch Time: 0.7147946357727051s;
# 12it [00:08,  1.38it/s]
# Batch Loss: 279996.875; Batch Time: 0.7047312259674072s;
# 13it [00:09,  1.39it/s]
# Batch Loss: 177131.96875; Batch Time: 0.7365100383758545s;
# 14it [00:10,  1.38it/s]
# Batch Loss: 177693.515625; Batch Time: 0.7240989208221436s;
# 15it [00:11,  1.38it/s]
# 15it [00:11,  1.36it/s]
# Epoch Loss: 214645.23645833333; Epoch Time: 11.052642822265625s;
# Evaluating Model ..
# AUC:0.5894983238931916; Avg Precision:0.437597844901477;
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_SVDD_Center.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_6.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_4.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/train_loss.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_8.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/eval_metrics.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_0.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_2.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_10.pt...
# iteration 10 finish.
# iteration 11 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 234730.59375; Batch Time: 0.795250415802002s;
# 1it [00:00,  1.26it/s]
# Batch Loss: 203509.96875; Batch Time: 0.7236473560333252s;
# 2it [00:01,  1.33it/s]
# Batch Loss: 72322.7421875; Batch Time: 0.7545411586761475s;
# 3it [00:02,  1.33it/s]
# Batch Loss: 204144.453125; Batch Time: 0.8092443943023682s;
# 4it [00:03,  1.29it/s]
# Batch Loss: 302283.0; Batch Time: 0.7059190273284912s;
# 5it [00:03,  1.33it/s]
# Batch Loss: 90241.6015625; Batch Time: 0.7599825859069824s;
# 6it [00:04,  1.33it/s]
# Batch Loss: 216331.5; Batch Time: 0.7153851985931396s;
# 7it [00:05,  1.35it/s]
# Batch Loss: 111028.0546875; Batch Time: 0.7346947193145752s;
# 8it [00:06,  1.35it/s]
# Batch Loss: 128507.4140625; Batch Time: 0.744762659072876s;
# 9it [00:06,  1.35it/s]
# Batch Loss: 152257.96875; Batch Time: 0.7324633598327637s;
# 10it [00:07,  1.35it/s]
# Batch Loss: 251049.515625; Batch Time: 0.6980838775634766s;
# 11it [00:08,  1.38it/s]
# Batch Loss: 160726.28125; Batch Time: 0.7405931949615479s;
# 12it [00:08,  1.37it/s]
# Batch Loss: 186220.875; Batch Time: 0.7415599822998047s;
# 13it [00:09,  1.36it/s]
# Batch Loss: 306313.375; Batch Time: 0.7490606307983398s;
# 14it [00:10,  1.35it/s]
# Batch Loss: 299304.6875; Batch Time: 0.6966331005096436s;
# 15it [00:11,  1.38it/s]
# 15it [00:11,  1.35it/s]
# Epoch Loss: 194598.13541666666; Epoch Time: 11.105785846710205s;
# iteration 11 finish.
# iteration 12 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 243666.15625; Batch Time: 0.7609775066375732s;
# 1it [00:00,  1.31it/s]
# Batch Loss: 175008.671875; Batch Time: 0.728295087814331s;
# 2it [00:01,  1.35it/s]
# Batch Loss: 316410.0625; Batch Time: 0.712766170501709s;
# 3it [00:02,  1.37it/s]
# Batch Loss: 197854.59375; Batch Time: 0.7718307971954346s;
# 4it [00:02,  1.34it/s]
# Batch Loss: 281339.5625; Batch Time: 0.7725424766540527s;
# 5it [00:03,  1.32it/s]
# Batch Loss: 337251.78125; Batch Time: 0.7354719638824463s;
# 6it [00:04,  1.34it/s]
# Batch Loss: 206550.46875; Batch Time: 0.7074108123779297s;
# 7it [00:05,  1.36it/s]
# Batch Loss: 210696.953125; Batch Time: 0.7723920345306396s;
# 8it [00:05,  1.34it/s]
# Batch Loss: 234386.328125; Batch Time: 0.732917070388794s;
# 9it [00:06,  1.35it/s]
# Batch Loss: 172962.234375; Batch Time: 0.7239243984222412s;
# 10it [00:07,  1.36it/s]
# Batch Loss: 319742.5625; Batch Time: 0.7379152774810791s;
# 11it [00:08,  1.36it/s]
# Batch Loss: 205116.078125; Batch Time: 0.719663143157959s;
# 12it [00:08,  1.37it/s]
# Batch Loss: 331014.25; Batch Time: 0.7248404026031494s;
# 13it [00:09,  1.37it/s]
# Batch Loss: 160580.765625; Batch Time: 0.7305033206939697s;
# 14it [00:10,  1.37it/s]
# Batch Loss: 237739.515625; Batch Time: 0.7111930847167969s;
# 15it [00:11,  1.38it/s]
# 15it [00:11,  1.36it/s]
# Epoch Loss: 242021.33229166668; Epoch Time: 11.046820878982544s;
# Evaluating Model ..
# AUC:0.5328438069216759; Avg Precision:0.4546790908935867;
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_SVDD_Center.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_6.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_4.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/train_loss.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_8.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_12.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/eval_metrics.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_0.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_2.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_10.pt...
# iteration 12 finish.
# iteration 13 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 250935.890625; Batch Time: 0.7339315414428711s;
# 1it [00:00,  1.36it/s]
# Batch Loss: 240564.390625; Batch Time: 0.7264633178710938s;
# 2it [00:01,  1.37it/s]
# Batch Loss: 317054.0; Batch Time: 0.7135248184204102s;
# 3it [00:02,  1.38it/s]
# Batch Loss: 305807.15625; Batch Time: 0.7105112075805664s;
# 4it [00:02,  1.39it/s]
# Batch Loss: 132511.78125; Batch Time: 0.7024235725402832s;
# 5it [00:03,  1.40it/s]
# Batch Loss: 280348.1875; Batch Time: 0.7211058139801025s;
# 6it [00:04,  1.40it/s]
# Batch Loss: 250459.875; Batch Time: 0.7143478393554688s;
# 7it [00:05,  1.40it/s]
# Batch Loss: 278125.90625; Batch Time: 0.7147440910339355s;
# 8it [00:05,  1.40it/s]
# Batch Loss: 208521.5; Batch Time: 0.7243809700012207s;
# 9it [00:06,  1.39it/s]
# Batch Loss: 275697.0; Batch Time: 0.718472957611084s;
# 10it [00:07,  1.39it/s]
# Batch Loss: 196900.578125; Batch Time: 0.7275559902191162s;
# 11it [00:07,  1.39it/s]
# Batch Loss: 241836.921875; Batch Time: 0.7615399360656738s;
# 12it [00:08,  1.36it/s]
# Batch Loss: 230030.75; Batch Time: 0.7157590389251709s;
# 13it [00:09,  1.37it/s]
# Batch Loss: 167946.953125; Batch Time: 0.7207901477813721s;
# 14it [00:10,  1.38it/s]
# Batch Loss: 155326.75; Batch Time: 0.7710602283477783s;
# 15it [00:10,  1.35it/s]
# 15it [00:10,  1.38it/s]
# Epoch Loss: 235471.17604166668; Epoch Time: 10.88077163696289s;
# iteration 13 finish.
# iteration 14 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 179181.875; Batch Time: 0.7601628303527832s;
# 1it [00:00,  1.32it/s]
# Batch Loss: 237555.59375; Batch Time: 0.7061958312988281s;
# 2it [00:01,  1.37it/s]
# Batch Loss: 211635.71875; Batch Time: 0.7255728244781494s;
# 3it [00:02,  1.37it/s]
# Batch Loss: 191541.59375; Batch Time: 0.7575714588165283s;
# 4it [00:02,  1.35it/s]
# Batch Loss: 291539.75; Batch Time: 0.7872602939605713s;
# 5it [00:03,  1.32it/s]
# Batch Loss: 315688.4375; Batch Time: 0.768139123916626s;
# 6it [00:04,  1.31it/s]
# Batch Loss: 184133.859375; Batch Time: 0.6983704566955566s;
# 7it [00:05,  1.35it/s]
# Batch Loss: 239365.21875; Batch Time: 0.7399015426635742s;
# 8it [00:05,  1.35it/s]
# Batch Loss: 159383.140625; Batch Time: 0.7057619094848633s;
# 9it [00:06,  1.37it/s]
# Batch Loss: 141223.578125; Batch Time: 0.7035071849822998s;
# 10it [00:07,  1.39it/s]
# Batch Loss: 239918.46875; Batch Time: 0.7350351810455322s;
# 11it [00:08,  1.38it/s]
# Batch Loss: 209877.328125; Batch Time: 0.7165312767028809s;
# 12it [00:08,  1.38it/s]
# Batch Loss: 204230.078125; Batch Time: 0.7150890827178955s;
# 13it [00:09,  1.39it/s]
# Batch Loss: 116493.15625; Batch Time: 0.7173707485198975s;
# 14it [00:10,  1.39it/s]
# Batch Loss: 241261.390625; Batch Time: 0.7305922508239746s;
# 15it [00:10,  1.38it/s]
# 15it [00:10,  1.37it/s]
# Epoch Loss: 210868.6125; Epoch Time: 10.971337795257568s;
# Evaluating Model ..
# AUC:0.6174709302325581; Avg Precision:0.44424299295326514;
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_SVDD_Center.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_6.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_14.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_4.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/train_loss.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_8.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_12.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/eval_metrics.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_0.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_2.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_10.pt...
# iteration 14 finish.
# iteration 15 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 208384.28125; Batch Time: 0.7736353874206543s;
# 1it [00:00,  1.29it/s]
# Batch Loss: 165221.0; Batch Time: 0.7107527256011963s;
# 2it [00:01,  1.36it/s]
# Batch Loss: 246920.171875; Batch Time: 0.7292842864990234s;
# 3it [00:02,  1.36it/s]
# Batch Loss: 200689.140625; Batch Time: 0.7406389713287354s;
# 4it [00:02,  1.36it/s]
# Batch Loss: 168608.390625; Batch Time: 0.7369430065155029s;
# 5it [00:03,  1.36it/s]
# Batch Loss: 317915.15625; Batch Time: 0.725334644317627s;
# 6it [00:04,  1.36it/s]
# Batch Loss: 177240.390625; Batch Time: 0.7258727550506592s;
# 7it [00:05,  1.37it/s]
# Batch Loss: 123192.7578125; Batch Time: 0.7166156768798828s;
# 8it [00:05,  1.38it/s]
# Batch Loss: 250652.828125; Batch Time: 0.7720291614532471s;
# 9it [00:06,  1.35it/s]
# Batch Loss: 267103.625; Batch Time: 0.7058606147766113s;
# 10it [00:07,  1.37it/s]
# Batch Loss: 238530.109375; Batch Time: 0.6967015266418457s;
# 11it [00:08,  1.39it/s]
# Batch Loss: 150709.890625; Batch Time: 0.7582380771636963s;
# 12it [00:08,  1.37it/s]
# Batch Loss: 281888.71875; Batch Time: 0.7391083240509033s;
# 13it [00:09,  1.36it/s]
# Batch Loss: 273293.78125; Batch Time: 0.7057528495788574s;
# 14it [00:10,  1.38it/s]
# Batch Loss: 212951.390625; Batch Time: 0.7193567752838135s;
# 15it [00:10,  1.38it/s]
# 15it [00:10,  1.37it/s]
# Epoch Loss: 218886.77552083333; Epoch Time: 10.960149765014648s;
# iteration 15 finish.
# iteration 16 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 209138.359375; Batch Time: 0.7567653656005859s;
# 1it [00:00,  1.32it/s]
# Batch Loss: 122843.6484375; Batch Time: 0.7486057281494141s;
# 2it [00:01,  1.33it/s]
# Batch Loss: 173621.25; Batch Time: 0.7179756164550781s;
# 3it [00:02,  1.36it/s]
# Batch Loss: 217194.671875; Batch Time: 0.7020654678344727s;
# 4it [00:02,  1.38it/s]
# Batch Loss: 200217.515625; Batch Time: 0.746218204498291s;
# 5it [00:03,  1.37it/s]
# Batch Loss: 173474.46875; Batch Time: 0.6982734203338623s;
# 6it [00:04,  1.39it/s]
# Batch Loss: 149467.578125; Batch Time: 0.7225737571716309s;
# 7it [00:05,  1.39it/s]
# Batch Loss: 212700.828125; Batch Time: 0.7218325138092041s;
# 8it [00:05,  1.39it/s]
# Batch Loss: 233487.515625; Batch Time: 0.6853682994842529s;
# 9it [00:06,  1.41it/s]
# Batch Loss: 170844.03125; Batch Time: 0.6859097480773926s;
# 10it [00:07,  1.42it/s]
# Batch Loss: 213190.640625; Batch Time: 0.7245416641235352s;
# 11it [00:07,  1.41it/s]
# Batch Loss: 300780.46875; Batch Time: 0.7507529258728027s;
# 12it [00:08,  1.38it/s]
# Batch Loss: 238676.078125; Batch Time: 0.7819297313690186s;
# 13it [00:09,  1.35it/s]
# Batch Loss: 241279.15625; Batch Time: 0.7643556594848633s;
# 14it [00:10,  1.34it/s]
# Batch Loss: 346694.21875; Batch Time: 0.7229757308959961s;
# 15it [00:10,  1.35it/s]
# 15it [00:10,  1.37it/s]
# Epoch Loss: 213574.02864583334; Epoch Time: 10.93401551246643s;
# Evaluating Model ..
# AUC:0.5704801694042236; Avg Precision:0.44966044770190117;
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_SVDD_Center.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_16.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_6.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_14.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_4.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/train_loss.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_8.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_12.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/eval_metrics.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_0.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_2.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_10.pt...
# iteration 16 finish.
# iteration 17 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 141227.25; Batch Time: 0.7129595279693604s;
# 1it [00:00,  1.40it/s]
# Batch Loss: 159221.5; Batch Time: 0.7274971008300781s;
# 2it [00:01,  1.39it/s]
# Batch Loss: 175597.234375; Batch Time: 0.74365234375s;
# 3it [00:02,  1.37it/s]
# Batch Loss: 327455.46875; Batch Time: 0.73146653175354s;
# 4it [00:02,  1.37it/s]
# Batch Loss: 168369.703125; Batch Time: 0.7510495185852051s;
# 5it [00:03,  1.35it/s]
# Batch Loss: 206035.640625; Batch Time: 0.7563881874084473s;
# 6it [00:04,  1.34it/s]
# Batch Loss: 211225.015625; Batch Time: 0.6913197040557861s;
# 7it [00:05,  1.37it/s]
# Batch Loss: 227484.640625; Batch Time: 0.7484962940216064s;
# 8it [00:05,  1.36it/s]
# Batch Loss: 187703.796875; Batch Time: 0.7162377834320068s;
# 9it [00:06,  1.37it/s]
# Batch Loss: 144839.34375; Batch Time: 0.7621939182281494s;
# 10it [00:07,  1.35it/s]
# Batch Loss: 349672.59375; Batch Time: 0.6871023178100586s;
# 11it [00:08,  1.38it/s]
# Batch Loss: 272085.40625; Batch Time: 0.6924009323120117s;
# 12it [00:08,  1.40it/s]
# Batch Loss: 277774.5; Batch Time: 0.722245454788208s;
# 13it [00:09,  1.40it/s]
# Batch Loss: 165001.109375; Batch Time: 0.7447547912597656s;
# 14it [00:10,  1.38it/s]
# Batch Loss: 237919.71875; Batch Time: 0.760230541229248s;
# 15it [00:10,  1.36it/s]
# 15it [00:10,  1.37it/s]
# Epoch Loss: 216774.19479166667; Epoch Time: 10.952000141143799s;
# iteration 17 finish.
# iteration 18 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 206278.390625; Batch Time: 0.7658658027648926s;
# 1it [00:00,  1.31it/s]
# Batch Loss: 217151.0; Batch Time: 0.736546516418457s;
# 2it [00:01,  1.34it/s]
# Batch Loss: 275783.625; Batch Time: 0.758629322052002s;
# 3it [00:02,  1.33it/s]
# ...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_104.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_278.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_78.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_154.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_138.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_176.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_144.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_236.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_112.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_276.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_76.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_80.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_36.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_244.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_292.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_130.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_6.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_294.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_64.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_238.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_134.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_248.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_148.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_228.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_106.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_178.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_14.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_258.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_140.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_52.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_150.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_136.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_262.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_22.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_48.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_4.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_196.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_234.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_60.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_54.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_96.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_88.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_72.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_164.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_90.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/train_loss.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_8.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_92.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_266.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_172.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_202.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_290.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_222.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_84.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_108.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_152.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_12.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_284.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_200.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_170.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_68.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_274.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_256.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_212.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_296.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_216.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_186.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_298.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_246.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_232.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/eval_metrics.txt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_174.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_146.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_250.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_102.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_32.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_34.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_166.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_214.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_114.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_156.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_210.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_28.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_0.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_264.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_184.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_126.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_38.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_208.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_30.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_116.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_272.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_42.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_58.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_218.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_40.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_122.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_242.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_226.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_94.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_26.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_268.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_158.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_66.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_192.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_220.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_206.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_142.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_70.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_194.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_100.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_46.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_286.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_118.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_182.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_2.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_188.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_270.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_120.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_132.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_44.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_110.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_18.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_74.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_230.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_280.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_62.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_288.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_162.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_168.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_254.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_10.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_124.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_282.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_190.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_98.pt...
# Uploading application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn9/HetGNN_56.pt...
# iteration 298 finish.
# iteration 299 ...
# Sampling 375 input data samples
# Epoch data input size: (15, 25)
# 0it [00:00, ?it/s]
# Batch Loss: 261378.078125; Batch Time: 0.724029541015625s;
# 1it [00:00,  1.38it/s]
# Batch Loss: 168638.4375; Batch Time: 0.7242398262023926s;
# 2it [00:01,  1.38it/s]
# Batch Loss: 275048.46875; Batch Time: 0.7448055744171143s;
# 3it [00:02,  1.36it/s]
# Batch Loss: 319584.90625; Batch Time: 0.7485885620117188s;
# 4it [00:02,  1.35it/s]
# Batch Loss: 125430.6953125; Batch Time: 0.730370044708252s;
# 5it [00:03,  1.36it/s]
# Batch Loss: 276963.4375; Batch Time: 0.7480518817901611s;
# 6it [00:04,  1.35it/s]
# Batch Loss: 155521.03125; Batch Time: 0.7880847454071045s;
# 7it [00:05,  1.32it/s]
# Batch Loss: 368707.125; Batch Time: 0.7007699012756348s;
# 8it [00:05,  1.35it/s]
# Batch Loss: 290208.21875; Batch Time: 0.7414851188659668s;
# 9it [00:06,  1.35it/s]
# Batch Loss: 192787.78125; Batch Time: 0.7360169887542725s;
# 10it [00:07,  1.35it/s]
# Batch Loss: 146067.65625; Batch Time: 0.7390034198760986s;
# 11it [00:08,  1.35it/s]
# Batch Loss: 270264.46875; Batch Time: 0.7752771377563477s;
# 12it [00:08,  1.33it/s]
# Batch Loss: 210250.140625; Batch Time: 0.7114450931549072s;
# 13it [00:09,  1.35it/s]
# Batch Loss: 117166.4375; Batch Time: 0.7012648582458496s;
# 14it [00:10,  1.38it/s]
# Batch Loss: 268848.71875; Batch Time: 0.7017056941986084s;
# 15it [00:11,  1.39it/s]
# 15it [00:11,  1.36it/s]
# Epoch Loss: 229791.04010416666; Epoch Time: 11.019100904464722s;
# iteration 299 finish.
# 2022-09-25 08:32:21,574 sagemaker-training-toolkit INFO     Waiting for the process to finish and give a return code.
# 2022-09-25 08:32:21,574 sagemaker-training-toolkit INFO     Done waiting for a return code. Received 0 from exiting process.
# 2022-09-25 08:32:21,574 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2022-09-25 08:32:28 Uploading - Uploading generated training model
# 2022-09-25 08:33:05 Completed - Training job completed
# ProfilerReport-1664088647: IssuesFound
# Training seconds: 6031
# Billable seconds: 6031
