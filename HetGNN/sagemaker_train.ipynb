# %%
# !pip install -U sagemaker
# Out:
# Requirement already satisfied: sagemaker in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.106.0)
# Collecting sagemaker
#   Downloading sagemaker-2.108.0.tar.gz (570 kB)
#      |████████████████████████████████| 570 kB 26.7 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: attrs<22,>=20.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (20.3.0)
# Requirement already satisfied: boto3<2.0,>=1.20.21 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.23.10)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.19.5)
# Requirement already satisfied: protobuf<4.0,>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (3.15.2)
# Requirement already satisfied: protobuf3-to-dict<1.0,>=0.1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.1.5)
# Requirement already satisfied: smdebug_rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: importlib-metadata<5.0,>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (3.7.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (21.3)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.1.5)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.2.8)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0,>=1.20.21->sagemaker) (0.5.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0,>=1.20.21->sagemaker) (0.10.0)
# Requirement already satisfied: botocore<1.27.0,>=1.26.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3<2.0,>=1.20.21->sagemaker) (1.26.10)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata<5.0,>=1.4.0->sagemaker) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata<5.0,>=1.4.0->sagemaker) (4.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging>=20.0->sagemaker) (2.4.7)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from protobuf<4.0,>=3.1->sagemaker) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas->sagemaker) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas->sagemaker) (2021.1)
# Requirement already satisfied: ppft>=1.6.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (1.6.6.4)
# Requirement already satisfied: pox>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.3.0)
# Requirement already satisfied: dill>=0.3.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.3.4)
# Requirement already satisfied: multiprocess>=0.70.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.70.12.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.27.0,>=1.26.10->boto3<2.0,>=1.20.21->sagemaker) (1.26.8)
# Building wheels for collected packages: sagemaker
#   Building wheel for sagemaker (setup.py) ... done
#   Created wheel for sagemaker: filename=sagemaker-2.108.0-py2.py3-none-any.whl size=786311 sha256=9478c05a6e92a413f133544f738b3eee9358f30670bbc772ddf95f46a6929d44
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/4b/90/af/d2a0e5f4b30891684260d6d76084a39c3d584f748a8f4a398f
# Successfully built sagemaker
# Installing collected packages: sagemaker
#   Attempting uninstall: sagemaker
#     Found existing installation: sagemaker 2.106.0
#     Uninstalling sagemaker-2.106.0:
#       Successfully uninstalled sagemaker-2.106.0
# Successfully installed sagemaker-2.108.0

# %%
from sagemaker import get_execution_role
from sagemaker.pytorch.estimator import PyTorch

role = get_execution_role()
role
# Out:
# 'arn:aws:iam::666048841835:role/prod-bi-analy-ml-pltf-sagemaker-exec-role'

# %%
# GCN_3
# hyperparameters = dict(
#     feature_size=26,
#     out_embed_s=32,
#     num_node_types=8,
#     num_train=375,
#     num_eval=225,
#     batch_s=125,
#     mini_batch_s=125,
#     hidden_channels=16,
#     save_model_freq=2,
#     lr=0.005,
#     train_iter_n=200,
#     model_version=3,
#     ignore_weight=False,
#     split_data=False,
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_sum'
# )
# hyperparameters

# %%
# # GCN_7 StreamSpot
# hyperparameters = dict(
#     feature_size=26,
#     out_embed_s=26,
#     num_hidden_conv_layers=2,
#     num_node_types=8,
#     source_types='0,1',
#     num_train=375,
#     num_eval=225,
#     batch_s=25,
#     mini_batch_s=25,
#     input_type='batch',
#     hidden_channels=26,
#     save_model_freq=2,
#     lr=0.001,
#     train_iter_n=100,
#     model_version=7,
#     ignore_weight=True,
#     split_data=False,
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn_v7_no_weight_h2'
# )
# hyperparameters

# %%
# GCN_3
# hyperparameters = dict(
#     feature_size=26,
#     out_embed_s=26,
#     num_node_types=8,
#     num_train=375,
#     num_eval=225,
#     batch_s=125,
#     mini_batch_s=125,
#     hidden_channels=26,
#     save_model_freq=2,
#     lr=0.005,
#     train_iter_n=200,
#     model_version=3,
#     ignore_weight=False,
#     split_data=False,
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn3'
# )
# hyperparameters

# %%
# GCN_3_1
# hyperparameters = dict(
#     feature_size=26,
#     out_embed_s=26,
#     num_node_types=8,
#     num_train=375,
#     num_eval=225,
#     batch_s=125,
#     mini_batch_s=125,
#     hidden_channels=26,
#     save_model_freq=2,
#     lr=0.005,
#     seed=10,
#     train_iter_n=200,
#     model_version=3,
#     model_sub_version=1,
#     ignore_weight=False,
#     split_data=False,
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_gcn3_1'
# )
# hyperparameters

# %%
# GCN_3_1 Streamspot

# python main.py \
# --sagemaker False \
# --num_node_types 8 \
# --num_train 375 \
# --batch_s 125 \
# --mini_batch_s 125 \
# --num_eval 225 \
# --hidden_channels 26 \
# --seed 10 \
# --s3_stage False \
# --split_data False \
# --ignore_weight False \
# --test_set True \
# --save_model_freq 2 \
# --lr 0.005 \
# --train_iter_n 200 \
# --model_version 3 \
# --model_sub_version 1 \
# --dataset_id 0 \
# --feature_size 26 \
# --out_embed_s 26 \
# --model_path ../model_save_HetGCN_streamspot_weight \
# --data_path ../ProcessedData_streamspot

# %%
# # GCN_3_1 TraLog
# hyperparameters = dict(
#     feature_size=7,
#     out_embed_s=16,
#     hidden_channels=16,
#     num_node_types=8,
#     num_train=65000,
#     num_eval=30000,
#     batch_s=500,
#     mini_batch_s=500,
#     save_model_freq=2,
#     lr=0.001,
#     seed=10,
#     train_iter_n=200,
#     model_version=3,
#     model_sub_version=1,
#     ignore_weight=False,
#     split_data=False,
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn3_1'
# )
# hyperparameters

# %%
# # GCN_3 TraLog
# hyperparameters = dict(
#     feature_size=7,
#     out_embed_s=16,
#     hidden_channels=16,
#     num_node_types=8,
#     num_train=65000,
#     num_eval=30000,
#     batch_s=500,
#     mini_batch_s=500,
#     save_model_freq=2,
#     lr=0.001,
#     seed=10,
#     train_iter_n=200,
#     model_version=3,
#     model_sub_version=0,
#     ignore_weight=False,
#     split_data=True,
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn3'
# )
# hyperparameters

# %%
# GCN_4 TraLog
# hyperparameters = dict(
#     feature_size=7,
#     out_embed_s=16,
#     hidden_channels=16,
#     num_node_types=8,
#     num_train=65000,
#     num_eval=30000,
#     batch_s=500,
#     mini_batch_s=500,
#     save_model_freq=2,
#     lr=0.001,
#     seed=10,
#     train_iter_n=200,
#     model_version=4,
#     model_sub_version=0,
#     source_types='0,1,2,3,4,5,6,7',
#     ignore_weight=False,
#     split_data=True,
#     input_type='batch',
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn4'
# )
# hyperparameters

# %%
# # GCN_8 TraLog
hyperparameters = dict(
    feature_size=7,
    out_embed_s=300,
    hidden_channels=300,
    num_hidden_conv_layers=3,
    num_node_types=8,
    num_edge_types=4,
    num_train=65000,
    sampling_size=3200,
    eval_size=10000,
    batch_s=8,
    mini_batch_s=8,
    save_model_freq=2,
    lr=0.0001,
    train_iter_n=400,
    model_version=8,
    model_sub_version=0,  # Model Sub Version
    source_types='0,1,2,3,4,5,6,7',
    ignore_weight=True,
    split_data=False,
    input_type='batch',
    s3_stage=True,
    s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn8_h3_noweight'
)
hyperparameters
# Out:
# {'feature_size': 7,
#  'out_embed_s': 300,
#  'hidden_channels': 300,
#  'num_hidden_conv_layers': 3,
#  'num_node_types': 8,
#  'num_edge_types': 4,
#  'num_train': 65000,
#  'sampling_size': 3200,
#  'eval_size': 10000,
#  'batch_s': 8,
#  'mini_batch_s': 8,
#  'save_model_freq': 2,
#  'lr': 0.0001,
#  'train_iter_n': 400,
#  'model_version': 8,
#  'model_sub_version': 0,
#  'source_types': '0,1,2,3,4,5,6,7',
#  'ignore_weight': True,
#  'split_data': False,
#  'input_type': 'batch',
#  's3_stage': True,
#  's3_prefix': 'application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn8_h3_noweight'}

# %%
# # GCN_7 TraLog
# hyperparameters = dict(
#     feature_size=7,
#     out_embed_s=300,
#     hidden_channels=300,
#     num_hidden_conv_layers=2,
#     num_node_types=8,
#     num_train=65000,
#     sampling_size=3200,
#     eval_size=10000,
#     batch_s=64,
#     mini_batch_s=64,
#     save_model_freq=2,
#     lr=0.0001,
#     train_iter_n=1000,
#     model_version=7,
#     model_sub_version=0,  # Model Sub Version
#     source_types='0,1,2,3,4,5,6,7',
#     ignore_weight=False,
#     split_data=False,
#     input_type='batch',
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn70_h2_simple_weight_batch64'
# )
# hyperparameters

# %%
# # GCN_9 TraLog
# hyperparameters = dict(
#     feature_size=7,
#     out_embed_s=300,
#     hidden_channels=300,
#     num_edge_types=4,
#     num_train=65000,
#     sampling_size=3200,
#     eval_size=10000,
#     batch_s=32,
#     mini_batch_s=32,
#     save_model_freq=2,
#     lr=0.0001,
#     train_iter_n=200,
#     model_version=9,
#     model_sub_version=0,  # Model Sub Version
#     ignore_weight=True,
#     split_data=False,
#     input_type='batch',
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn9'
# )
# hyperparameters

# %%
# GCN_SUM
# hyperparameters = dict(
#     feature_size=26,
#     out_embed_s=26,
#     num_node_types=8,
#     num_train=375,
#     num_eval=225,
#     batch_s=125,
#     mini_batch_s=125,
#     hidden_channels=26,
#     save_model_freq=2,
#     lr=0.005,
#     train_iter_n=200,
#     model_version=3,
#     ignore_weight=False,
#     split_data=False,
#     s3_stage=True,
#     s3_prefix='application/anomaly_detection/deeptralog/HetGNN/model_save_streamspot_combine_g_before_concat'
# )
# hyperparameters

# %%
estimator = PyTorch(
    source_dir='./code_gcn/',
    entry_point='main.py',
#     framework_version='1.9.1',
#     py_version='py38',
    image_uri='666048841835.dkr.ecr.ap-southeast-2.amazonaws.com/pytorch-hetgcn:latest',
    instance_type='ml.g4dn.2xlarge',
    instance_count=1,
    volume_size=150,
    max_run=24*60*60*2,
    role=role,
    base_job_name='HetGNN',
    hyperparameters=hyperparameters,
    metric_definitions=[
        {
            "Name": "Loss",
            "Regex": "Epoch Loss: (.*?);",
        },
        {
            "Name": "Batch Loss",
            "Regex": "Batch Loss: (.*?);",
        },
        {
            "Name": "Epoch Time",
            "Regex": "Epoch Time: (.*?);",
        },
        {
            "Name": "Batch Time",
            "Regex": "Batch Time: (.*?);",
        },
        {
            "Name": "AUC",
            "Regex": "AUC:(.*?);",
        },
        {
            "Name": "AP",
            "Regex": "Avg Precision:(.*?);"
        }
    ]
)

# %%
estimator.fit(
    {
#         'train': 's3://prod-tpgt-knowledge-lake-sandpit-v1/application/anomaly_detection/deeptralog/HetGNN/ProcessedData_synth/'
#         'train': 's3://prod-tpgt-knowledge-lake-sandpit-v1/application/anomaly_detection/deeptralog/HetGNN/ProcessedData_clean/'
        'train': 's3://prod-tpgt-knowledge-lake-sandpit-v1/application/anomaly_detection/deeptralog/HetGNN/ProcessedData_HetGCN/'
#         'train': 's3://prod-tpgt-knowledge-lake-sandpit-v1/application/anomaly_detection/deeptralog/HetGNN/ProcessedData_streamspot/'
    }
)
# Out:
# 2022-09-06 01:05:35 Starting - Starting the training job...
# 2022-09-06 01:05:58 Starting - Preparing the instances for trainingProfilerReport-1662426335: InProgress
# .........
# 2022-09-06 01:07:19 Downloading - Downloading input data..................
# 2022-09-06 01:10:20 Training - Downloading the training image...............
# 2022-09-06 01:13:00 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-09-06 01:13:03,029 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-09-06 01:13:03,059 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-09-06 01:13:03,066 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-09-06 01:13:03,625 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1"
#     ],
#     "current_instance_type": "ml.g4dn.2xlarge",
#     "distribution_hosts": [],
#     "distribution_instance_groups": [],
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_s": 8,
#         "eval_size": 10000,
#         "feature_size": 7,
#         "hidden_channels": 300,
#         "ignore_weight": true,
#         "input_type": "batch",
#         "lr": 0.0001,
#         "mini_batch_s": 8,
#         "model_sub_version": 0,
#         "model_version": 8,
#         "num_edge_types": 4,
#         "num_hidden_conv_layers": 3,
#         "num_node_types": 8,
#         "num_train": 65000,
#         "out_embed_s": 300,
#         "s3_prefix": "application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn8_h3_noweight",
#         "s3_stage": true,
#         "sampling_size": 3200,
#         "save_model_freq": 2,
#         "source_types": "0,1,2,3,4,5,6,7",
#         "split_data": false,
#         "train_iter_n": 400
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.g4dn.2xlarge",
#             "hosts": [
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "job_name": "HetGNN-2022-09-06-01-05-34-729",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-southeast-2-666048841835/HetGNN-2022-09-06-01-05-34-729/source/sourcedir.tar.gz",
#     "module_name": "main",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.g4dn.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.g4dn.2xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "main.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_s":8,"eval_size":10000,"feature_size":7,"hidden_channels":300,"ignore_weight":true,"input_type":"batch","lr":0.0001,"mini_batch_s":8,"model_sub_version":0,"model_version":8,"num_edge_types":4,"num_hidden_conv_layers":3,"num_node_types":8,"num_train":65000,"out_embed_s":300,"s3_prefix":"application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn8_h3_noweight","s3_stage":true,"sampling_size":3200,"save_model_freq":2,"source_types":"0,1,2,3,4,5,6,7","split_data":false,"train_iter_n":400}
# SM_USER_ENTRY_POINT=main.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.g4dn.2xlarge
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.2xlarge"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# SM_IS_HETERO=false
# SM_MODULE_NAME=main
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-southeast-2-666048841835/HetGNN-2022-09-06-01-05-34-729/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1"],"current_instance_type":"ml.g4dn.2xlarge","distribution_hosts":[],"distribution_instance_groups":[],"framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_s":8,"eval_size":10000,"feature_size":7,"hidden_channels":300,"ignore_weight":true,"input_type":"batch","lr":0.0001,"mini_batch_s":8,"model_sub_version":0,"model_version":8,"num_edge_types":4,"num_hidden_conv_layers":3,"num_node_types":8,"num_train":65000,"out_embed_s":300,"s3_prefix":"application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn8_h3_noweight","s3_stage":true,"sampling_size":3200,"save_model_freq":2,"source_types":"0,1,2,3,4,5,6,7","split_data":false,"train_iter_n":400},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.2xlarge"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"job_name":"HetGNN-2022-09-06-01-05-34-729","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-southeast-2-666048841835/HetGNN-2022-09-06-01-05-34-729/source/sourcedir.tar.gz","module_name":"main","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g4dn.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g4dn.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"main.py"}
# SM_USER_ARGS=["--batch_s","8","--eval_size","10000","--feature_size","7","--hidden_channels","300","--ignore_weight","True","--input_type","batch","--lr","0.0001","--mini_batch_s","8","--model_sub_version","0","--model_version","8","--num_edge_types","4","--num_hidden_conv_layers","3","--num_node_types","8","--num_train","65000","--out_embed_s","300","--s3_prefix","application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn8_h3_noweight","--s3_stage","True","--sampling_size","3200","--save_model_freq","2","--source_types","0,1,2,3,4,5,6,7","--split_data","False","--train_iter_n","400"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_BATCH_S=8
# SM_HP_EVAL_SIZE=10000
# SM_HP_FEATURE_SIZE=7
# SM_HP_HIDDEN_CHANNELS=300
# SM_HP_IGNORE_WEIGHT=true
# SM_HP_INPUT_TYPE=batch
# SM_HP_LR=0.0001
# SM_HP_MINI_BATCH_S=8
# SM_HP_MODEL_SUB_VERSION=0
# SM_HP_MODEL_VERSION=8
# SM_HP_NUM_EDGE_TYPES=4
# SM_HP_NUM_HIDDEN_CONV_LAYERS=3
# SM_HP_NUM_NODE_TYPES=8
# SM_HP_NUM_TRAIN=65000
# SM_HP_OUT_EMBED_S=300
# SM_HP_S3_PREFIX=application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn8_h3_noweight
# SM_HP_S3_STAGE=true
# SM_HP_SAMPLING_SIZE=3200
# SM_HP_SAVE_MODEL_FREQ=2
# SM_HP_SOURCE_TYPES=0,1,2,3,4,5,6,7
# SM_HP_SPLIT_DATA=false
# SM_HP_TRAIN_ITER_N=400
# PYTHONPATH=/opt/ml/code:/opt/conda/lib/python3.8/site-packages/smdistributed/dataparallel/lib:/opt/conda/bin:/opt/conda/lib/python38.zip:/opt/conda/lib/python3.8:/opt/conda/lib/python3.8/lib-dynload:/opt/conda/lib/python3.8/site-packages:/opt/conda/lib/python3.8/site-packages/smdebug-1.0.16b20220801-py3.8.egg:/opt/conda/lib/python3.8/site-packages/pyinstrument-3.4.2-py3.8.egg:/opt/conda/lib/python3.8/site-packages/pyinstrument_cext-0.2.4-py3.8-linux-x86_64.egg
# Invoking script with the following command:
# /opt/conda/bin/python3.8 main.py --batch_s 8 --eval_size 10000 --feature_size 7 --hidden_channels 300 --ignore_weight True --input_type batch --lr 0.0001 --mini_batch_s 8 --model_sub_version 0 --model_version 8 --num_edge_types 4 --num_hidden_conv_layers 3 --num_node_types 8 --num_train 65000 --out_embed_s 300 --s3_prefix application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn8_h3_noweight --s3_stage True --sampling_size 3200 --save_model_freq 2 --source_types 0,1,2,3,4,5,6,7 --split_data False --train_iter_n 400
# {'batch_s': 8, 'eval_size': 10000, 'feature_size': 7, 'hidden_channels': 300, 'ignore_weight': True, 'input_type': 'batch', 'lr': 0.0001, 'mini_batch_s': 8, 'model_sub_version': 0, 'model_version': 8, 'num_edge_types': 4, 'num_hidden_conv_layers': 3, 'num_node_types': 8, 'num_train': 65000, 'out_embed_s': 300, 's3_prefix': 'application/anomaly_detection/deeptralog/HetGNN/model_save_tralog_gcn8_h3_noweight', 's3_stage': True, 'sampling_size': 3200, 'save_model_freq': 2, 'source_types': '0,1,2,3,4,5,6,7', 'split_data': False, 'train_iter_n': 400, 'model_path': '/opt/ml/model', 'data_path': '/opt/ml/input/data/train', 'num_eval': None, 'seed': 32, 'dataset_id': 0, 'fix_center': True, 'test_set': True, 'sagemaker': True, 'unzip': True, 's3_bucket': 'prod-tpgt-knowledge-lake-sandpit-v1'}
# Device: cuda
# reading node features..
# reading edge index..
# Ignore Edge Weights.
# read node types ..
# node types txt: 132485
# done
# ModuleList(
#   (0): ModuleList(
#     (0): ModuleList(
#       (0): Linear(in_features=7, out_features=300, bias=True)
#       (1): Linear(in_features=7, out_features=300, bias=True)
#       (2): Linear(in_features=7, out_features=300, bias=True)
#       (3): Linear(in_features=7, out_features=300, bias=True)
#       (4): Linear(in_features=7, out_features=300, bias=True)
#       (5): Linear(in_features=7, out_features=300, bias=True)
#       (6): Linear(in_features=7, out_features=300, bias=True)
#       (7): Linear(in_features=7, out_features=300, bias=True)
#       (8): Linear(in_features=7, out_features=300, bias=True)
#       (9): Linear(in_features=7, out_features=300, bias=True)
#       (10): Linear(in_features=7, out_features=300, bias=True)
#       (11): Linear(in_features=7, out_features=300, bias=True)
#       (12): Linear(in_features=7, out_features=300, bias=True)
#       (13): Linear(in_features=7, out_features=300, bias=True)
#       (14): Linear(in_features=7, out_features=300, bias=True)
#       (15): Linear(in_features=7, out_features=300, bias=True)
#       (16): Linear(in_features=7, out_features=300, bias=True)
#       (17): Linear(in_features=7, out_features=300, bias=True)
#       (18): Linear(in_features=7, out_features=300, bias=True)
#       (19): Linear(in_features=7, out_features=300, bias=True)
#       (20): Linear(in_features=7, out_features=300, bias=True)
#       (21): Linear(in_features=7, out_features=300, bias=True)
#       (22): Linear(in_features=7, out_features=300, bias=True)
#       (23): Linear(in_features=7, out_features=300, bias=True)
#       (24): Linear(in_features=7, out_features=300, bias=True)
#       (25): Linear(in_features=7, out_features=300, bias=True)
#       (26): Linear(in_features=7, out_features=300, bias=True)
#       (27): Linear(in_features=7, out_features=300, bias=True)
#       (28): Linear(in_features=7, out_features=300, bias=True)
#       (29): Linear(in_features=7, out_features=300, bias=True)
#       (30): Linear(in_features=7, out_features=300, bias=True)
#       (31): Linear(in_features=7, out_features=300, bias=True)
#       (32): Linear(in_features=7, out_features=300, bias=True)
#       (33): Linear(in_features=7, out_features=300, bias=True)
#       (34): Linear(in_features=7, out_features=300, bias=True)
#       (35): Linear(in_features=7, out_features=300, bias=True)
#       (36): Linear(in_features=7, out_features=300, bias=True)
#       (37): Linear(in_features=7, out_features=300, bias=True)
#       (38): Linear(in_features=7, out_features=300, bias=True)
#       (39): Linear(in_features=7, out_features=300, bias=True)
#       (40): Linear(in_features=7, out_features=300, bias=True)
#       (41): Linear(in_features=7, out_features=300, bias=True)
#       (42): Linear(in_features=7, out_features=300, bias=True)
#       (43): Linear(in_features=7, out_features=300, bias=True)
#       (44): Linear(in_features=7, out_features=300, bias=True)
#       (45): Linear(in_features=7, out_features=300, bias=True)
#       (46): Linear(in_features=7, out_features=300, bias=True)
#       (47): Linear(in_features=7, out_features=300, bias=True)
#       (48): Linear(in_features=7, out_features=300, bias=True)
#       (49): Linear(in_features=7, out_features=300, bias=True)
#       (50): Linear(in_features=7, out_features=300, bias=True)
#       (51): Linear(in_features=7, out_features=300, bias=True)
#       (52): Linear(in_features=7, out_features=300, bias=True)
#       (53): Linear(in_features=7, out_features=300, bias=True)
#       (54): Linear(in_features=7, out_features=300, bias=True)
#       (55): Linear(in_features=7, out_features=300, bias=True)
#       (56): Linear(in_features=7, out_features=300, bias=True)
#       (57): Linear(in_features=7, out_features=300, bias=True)
#       (58): Linear(in_features=7, out_features=300, bias=True)
#       (59): Linear(in_features=7, out_features=300, bias=True)
#       (60): Linear(in_features=7, out_features=300, bias=True)
#       (61): Linear(in_features=7, out_features=300, bias=True)
#       (62): Linear(in_features=7, out_features=300, bias=True)
#       (63): Linear(in_features=7, out_features=300, bias=True)
#     )
#     (1): ModuleList(
#       (0): Linear(in_features=7, out_features=300, bias=True)
#       (1): Linear(in_features=7, out_features=300, bias=True)
#       (2): Linear(in_features=7, out_features=300, bias=True)
#       (3): Linear(in_features=7, out_features=300, bias=True)
#       (4): Linear(in_features=7, out_features=300, bias=True)
#       (5): Linear(in_features=7, out_features=300, bias=True)
#       (6): Linear(in_features=7, out_features=300, bias=True)
#       (7): Linear(in_features=7, out_features=300, bias=True)
#       (8): Linear(in_features=7, out_features=300, bias=True)
#       (9): Linear(in_features=7, out_features=300, bias=True)
#       (10): Linear(in_features=7, out_features=300, bias=True)
#       (11): Linear(in_features=7, out_features=300, bias=True)
#       (12): Linear(in_features=7, out_features=300, bias=True)
#       (13): Linear(in_features=7, out_features=300, bias=True)
#       (14): Linear(in_features=7, out_features=300, bias=True)
#       (15): Linear(in_features=7, out_features=300, bias=True)
#       (16): Linear(in_features=7, out_features=300, bias=True)
#       (17): Linear(in_features=7, out_features=300, bias=True)
#       (18): Linear(in_features=7, out_features=300, bias=True)
#       (19): Linear(in_features=7, out_features=300, bias=True)
#       (20): Linear(in_features=7, out_features=300, bias=True)
#       (21): Linear(in_features=7, out_features=300, bias=True)
#       (22): Linear(in_features=7, out_features=300, bias=True)
#       (23): Linear(in_features=7, out_features=300, bias=True)
#       (24): Linear(in_features=7, out_features=300, bias=True)
#       (25): Linear(in_features=7, out_features=300, bias=True)
#       (26): Linear(in_features=7, out_features=300, bias=True)
#       (27): Linear(in_features=7, out_features=300, bias=True)
#       (28): Linear(in_features=7, out_features=300, bias=True)
#       (29): Linear(in_features=7, out_features=300, bias=True)
#       (30): Linear(in_features=7, out_features=300, bias=True)
#       (31): Linear(in_features=7, out_features=300, bias=True)
#       (32): Linear(in_features=7, out_features=300, bias=True)
#       (33): Linear(in_features=7, out_features=300, bias=True)
#       (34): Linear(in_features=7, out_features=300, bias=True)
#       (35): Linear(in_features=7, out_features=300, bias=True)
#       (36): Linear(in_features=7, out_features=300, bias=True)
#       (37): Linear(in_features=7, out_features=300, bias=True)
#       (38): Linear(in_features=7, out_features=300, bias=True)
#       (39): Linear(in_features=7, out_features=300, bias=True)
#       (40): Linear(in_features=7, out_features=300, bias=True)
#       (41): Linear(in_features=7, out_features=300, bias=True)
#       (42): Linear(in_features=7, out_features=300, bias=True)
#       (43): Linear(in_features=7, out_features=300, bias=True)
#       (44): Linear(in_features=7, out_features=300, bias=True)
#       (45): Linear(in_features=7, out_features=300, bias=True)
#       (46): Linear(in_features=7, out_features=300, bias=True)
#       (47): Linear(in_features=7, out_features=300, bias=True)
#       (48): Linear(in_features=7, out_features=300, bias=True)
#       (49): Linear(in_features=7, out_features=300, bias=True)
#       (50): Linear(in_features=7, out_features=300, bias=True)
#       (51): Linear(in_features=7, out_features=300, bias=True)
#       (52): Linear(in_features=7, out_features=300, bias=True)
#       (53): Linear(in_features=7, out_features=300, bias=True)
#       (54): Linear(in_features=7, out_features=300, bias=True)
#       (55): Linear(in_features=7, out_features=300, bias=True)
#       (56): Linear(in_features=7, out_features=300, bias=True)
#       (57): Linear(in_features=7, out_features=300, bias=True)
#       (58): Linear(in_features=7, out_features=300, bias=True)
#       (59): Linear(in_features=7, out_features=300, bias=True)
#       (60): Linear(in_features=7, out_features=300, bias=True)
#       (61): Linear(in_features=7, out_features=300, bias=True)
#       (62): Linear(in_features=7, out_features=300, bias=True)
#       (63): Linear(in_features=7, out_features=300, bias=True)
#     )
#     (2): ModuleList(
#       (0): Linear(in_features=7, out_features=300, bias=True)
#       (1): Linear(in_features=7, out_features=300, bias=True)
#       (2): Linear(in_features=7, out_features=300, bias=True)
#       (3): Linear(in_features=7, out_features=300, bias=True)
#       (4): Linear(in_features=7, out_features=300, bias=True)
#       (5): Linear(in_features=7, out_features=300, bias=True)
#       (6): Linear(in_features=7, out_features=300, bias=True)
#       (7): Linear(in_features=7, out_features=300, bias=True)
#       (8): Linear(in_features=7, out_features=300, bias=True)
#       (9): Linear(in_features=7, out_features=300, bias=True)
#       (10): Linear(in_features=7, out_features=300, bias=True)
#       (11): Linear(in_features=7, out_features=300, bias=True)
#       (12): Linear(in_features=7, out_features=300, bias=True)
#       (13): Linear(in_features=7, out_features=300, bias=True)
#       (14): Linear(in_features=7, out_features=300, bias=True)
#       (15): Linear(in_features=7, out_features=300, bias=True)
#       (16): Linear(in_features=7, out_features=300, bias=True)
#       (17): Linear(in_features=7, out_features=300, bias=True)
#       (18): Linear(in_features=7, out_features=300, bias=True)
#       (19): Linear(in_features=7, out_features=300, bias=True)
#       (20): Linear(in_features=7, out_features=300, bias=True)
#       (21): Linear(in_features=7, out_features=300, bias=True)
#       (22): Linear(in_features=7, out_features=300, bias=True)
#       (23): Linear(in_features=7, out_features=300, bias=True)
#       (24): Linear(in_features=7, out_features=300, bias=True)
#       (25): Linear(in_features=7, out_features=300, bias=True)
#       (26): Linear(in_features=7, out_features=300, bias=True)
#       (27): Linear(in_features=7, out_features=300, bias=True)
#       (28): Linear(in_features=7, out_features=300, bias=True)
#       (29): Linear(in_features=7, out_features=300, bias=True)
#       (30): Linear(in_features=7, out_features=300, bias=True)
#       (31): Linear(in_features=7, out_features=300, bias=True)
#       (32): Linear(in_features=7, out_features=300, bias=True)
#       (33): Linear(in_features=7, out_features=300, bias=True)
#       (34): Linear(in_features=7, out_features=300, bias=True)
#       (35): Linear(in_features=7, out_features=300, bias=True)
#       (36): Linear(in_features=7, out_features=300, bias=True)
#       (37): Linear(in_features=7, out_features=300, bias=True)
#       (38): Linear(in_features=7, out_features=300, bias=True)
#       (39): Linear(in_features=7, out_features=300, bias=True)
#       (40): Linear(in_features=7, out_features=300, bias=True)
#       (41): Linear(in_features=7, out_features=300, bias=True)
#       (42): Linear(in_features=7, out_features=300, bias=True)
#       (43): Linear(in_features=7, out_features=300, bias=True)
#       (44): Linear(in_features=7, out_features=300, bias=True)
#       (45): Linear(in_features=7, out_features=300, bias=True)
#       (46): Linear(in_features=7, out_features=300, bias=True)
#       (47): Linear(in_features=7, out_features=300, bias=True)
#       (48): Linear(in_features=7, out_features=300, bias=True)
#       (49): Linear(in_features=7, out_features=300, bias=True)
#       (50): Linear(in_features=7, out_features=300, bias=True)
#       (51): Linear(in_features=7, out_features=300, bias=True)
#       (52): Linear(in_features=7, out_features=300, bias=True)
#       (53): Linear(in_features=7, out_features=300, bias=True)
#       (54): Linear(in_features=7, out_features=300, bias=True)
#       (55): Linear(in_features=7, out_features=300, bias=True)
#       (56): Linear(in_features=7, out_features=300, bias=True)
#       (57): Linear(in_features=7, out_features=300, bias=True)
#       (58): Linear(in_features=7, out_features=300, bias=True)
#       (59): Linear(in_features=7, out_features=300, bias=True)
#       (60): Linear(in_features=7, out_features=300, bias=True)
#       (61): Linear(in_features=7, out_features=300, bias=True)
#       (62): Linear(in_features=7, out_features=300, bias=True)
#       (63): Linear(in_features=7, out_features=300, bias=True)
#     )
#     (3): ModuleList(
#       (0): Linear(in_features=7, out_features=300, bias=True)
#       (1): Linear(in_features=7, out_features=300, bias=True)
#       (2): Linear(in_features=7, out_features=300, bias=True)
#       (3): Linear(in_features=7, out_features=300, bias=True)
#       (4): Linear(in_features=7, out_features=300, bias=True)
#       (5): Linear(in_features=7, out_features=300, bias=True)
#       (6): Linear(in_features=7, out_features=300, bias=True)
#       (7): Linear(in_features=7, out_features=300, bias=True)
#       (8): Linear(in_features=7, out_features=300, bias=True)
#       (9): Linear(in_features=7, out_features=300, bias=True)
#       (10): Linear(in_features=7, out_features=300, bias=True)
#       (11): Linear(in_features=7, out_features=300, bias=True)
#       (12): Linear(in_features=7, out_features=300, bias=True)
#       (13): Linear(in_features=7, out_features=300, bias=True)
#       (14): Linear(in_features=7, out_features=300, bias=True)
#       (15): Linear(in_features=7, out_features=300, bias=True)
#       (16): Linear(in_features=7, out_features=300, bias=True)
#       (17): Linear(in_features=7, out_features=300, bias=True)
#       (18): Linear(in_features=7, out_features=300, bias=True)
#       (19): Linear(in_features=7, out_features=300, bias=True)
#       (20): Linear(in_features=7, out_features=300, bias=True)
#       (21): Linear(in_features=7, out_features=300, bias=True)
#       (22): Linear(in_features=7, out_features=300, bias=True)
#       (23): Linear(in_features=7, out_features=300, bias=True)
#       (24): Linear(in_features=7, out_features=300, bias=True)
#       (25): Linear(in_features=7, out_features=300, bias=True)
#       (26): Linear(in_features=7, out_features=300, bias=True)
#       (27): Linear(in_features=7, out_features=300, bias=True)
#       (28): Linear(in_features=7, out_features=300, bias=True)
#       (29): Linear(in_features=7, out_features=300, bias=True)
#       (30): Linear(in_features=7, out_features=300, bias=True)
#       (31): Linear(in_features=7, out_features=300, bias=True)
#       (32): Linear(in_features=7, out_features=300, bias=True)
#       (33): Linear(in_features=7, out_features=300, bias=True)
#       (34): Linear(in_features=7, out_features=300, bias=True)
#       (35): Linear(in_features=7, out_features=300, bias=True)
#       (36): Linear(in_features=7, out_features=300, bias=True)
#       (37): Linear(in_features=7, out_features=300, bias=True)
#       (38): Linear(in_features=7, out_features=300, bias=True)
#       (39): Linear(in_features=7, out_features=300, bias=True)
#       (40): Linear(in_features=7, out_features=300, bias=True)
#       (41): Linear(in_features=7, out_features=300, bias=True)
#       (42): Linear(in_features=7, out_features=300, bias=True)
#       (43): Linear(in_features=7, out_features=300, bias=True)
#       (44): Linear(in_features=7, out_features=300, bias=True)
#       (45): Linear(in_features=7, out_features=300, bias=True)
#       (46): Linear(in_features=7, out_features=300, bias=True)
#       (47): Linear(in_features=7, out_features=300, bias=True)
#       (48): Linear(in_features=7, out_features=300, bias=True)
#       (49): Linear(in_features=7, out_features=300, bias=True)
#       (50): Linear(in_features=7, out_features=300, bias=True)
#       (51): Linear(in_features=7, out_features=300, bias=True)
#       (52): Linear(in_features=7, out_features=300, bias=True)
#       (53): Linear(in_features=7, out_features=300, bias=True)
#       (54): Linear(in_features=7, out_features=300, bias=True)
#       (55): Linear(in_features=7, out_features=300, bias=True)
#       (56): Linear(in_features=7, out_features=300, bias=True)
#       (57): Linear(in_features=7, out_features=300, bias=True)
#       (58): Linear(in_features=7, out_features=300, bias=True)
#       (59): Linear(in_features=7, out_features=300, bias=True)
#       (60): Linear(in_features=7, out_features=300, bias=True)
#       (61): Linear(in_features=7, out_features=300, bias=True)
#       (62): Linear(in_features=7, out_features=300, bias=True)
#       (63): Linear(in_features=7, out_features=300, bias=True)
#     )
#   )
#   (1): ModuleList(
#     (0): ModuleList(
#       (0): Linear(in_features=300, out_features=300, bias=True)
#       (1): Linear(in_features=300, out_features=300, bias=True)
#       (2): Linear(in_features=300, out_features=300, bias=True)
#       (3): Linear(in_features=300, out_features=300, bias=True)
#       (4): Linear(in_features=300, out_features=300, bias=True)
#       (5): Linear(in_features=300, out_features=300, bias=True)
#       (6): Linear(in_features=300, out_features=300, bias=True)
#       (7): Linear(in_features=300, out_features=300, bias=True)
#       (8): Linear(in_features=300, out_features=300, bias=True)
#       (9): Linear(in_features=300, out_features=300, bias=True)
#       (10): Linear(in_features=300, out_features=300, bias=True)
#       (11): Linear(in_features=300, out_features=300, bias=True)
#       (12): Linear(in_features=300, out_features=300, bias=True)
#       (13): Linear(in_features=300, out_features=300, bias=True)
#       (14): Linear(in_features=300, out_features=300, bias=True)
#       (15): Linear(in_features=300, out_features=300, bias=True)
#       (16): Linear(in_features=300, out_features=300, bias=True)
#       (17): Linear(in_features=300, out_features=300, bias=True)
#       (18): Linear(in_features=300, out_features=300, bias=True)
#       (19): Linear(in_features=300, out_features=300, bias=True)
#       (20): Linear(in_features=300, out_features=300, bias=True)
#       (21): Linear(in_features=300, out_features=300, bias=True)
#       (22): Linear(in_features=300, out_features=300, bias=True)
#       (23): Linear(in_features=300, out_features=300, bias=True)
#       (24): Linear(in_features=300, out_features=300, bias=True)
#       (25): Linear(in_features=300, out_features=300, bias=True)
#       (26): Linear(in_features=300, out_features=300, bias=True)
#       (27): Linear(in_features=300, out_features=300, bias=True)
#       (28): Linear(in_features=300, out_features=300, bias=True)
#       (29): Linear(in_features=300, out_features=300, bias=True)
#       (30): Linear(in_features=300, out_features=300, bias=True)
#       (31): Linear(in_features=300, out_features=300, bias=True)
#       (32): Linear(in_features=300, out_features=300, bias=True)
#       (33): Linear(in_features=300, out_features=300, bias=True)
#       (34): Linear(in_features=300, out_features=300, bias=True)
#       (35): Linear(in_features=300, out_features=300, bias=True)
#       (36): Linear(in_features=300, out_features=300, bias=True)
#       (37): Linear(in_features=300, out_features=300, bias=True)
#       (38): Linear(in_features=300, out_features=300, bias=True)
#       (39): Linear(in_features=300, out_features=300, bias=True)
#       (40): Linear(in_features=300, out_features=300, bias=True)
#       (41): Linear(in_features=300, out_features=300, bias=True)
#       (42): Linear(in_features=300, out_features=300, bias=True)
#       (43): Linear(in_features=300, out_features=300, bias=True)
#       (44): Linear(in_features=300, out_features=300, bias=True)
#       (45): Linear(in_features=300, out_features=300, bias=True)
#       (46): Linear(in_features=300, out_features=300, bias=True)
#       (47): Linear(in_features=300, out_features=300, bias=True)
#       (48): Linear(in_features=300, out_features=300, bias=True)
#       (49): Linear(in_features=300, out_features=300, bias=True)
#       (50): Linear(in_features=300, out_features=300, bias=True)
#       (51): Linear(in_features=300, out_features=300, bias=True)
#       (52): Linear(in_features=300, out_features=300, bias=True)
#       (53): Linear(in_features=300, out_features=300, bias=True)
#       (54): Linear(in_features=300, out_features=300, bias=True)
#       (55): Linear(in_features=300, out_features=300, bias=True)
#       (56): Linear(in_features=300, out_features=300, bias=True)
#       (57): Linear(in_features=300, out_features=300, bias=True)
#       (58): Linear(in_features=300, out_features=300, bias=True)
#       (59): Linear(in_features=300, out_features=300, bias=True)
#       (60): Linear(in_features=300, out_features=300, bias=True)
#       (61): Linear(in_features=300, out_features=300, bias=True)
#       (62): Linear(in_features=300, out_features=300, bias=True)
#       (63): Linear(in_features=300, out_features=300, bias=True)
#     )
#     (1): ModuleList(
#       (0): Linear(in_features=300, out_features=300, bias=True)
#       (1): Linear(in_features=300, out_features=300, bias=True)
#       (2): Linear(in_features=300, out_features=300, bias=True)
#       (3): Linear(in_features=300, out_features=300, bias=True)
#       (4): Linear(in_features=300, out_features=300, bias=True)
#       (5): Linear(in_features=300, out_features=300, bias=True)
#       (6): Linear(in_features=300, out_features=300, bias=True)
#       (7): Linear(in_features=300, out_features=300, bias=True)
#       (8): Linear(in_features=300, out_features=300, bias=True)
#       (9): Linear(in_features=300, out_features=300, bias=True)
#       (10): Linear(in_features=300, out_features=300, bias=True)
#       (11): Linear(in_features=300, out_features=300, bias=True)
#       (12): Linear(in_features=300, out_features=300, bias=True)
#       (13): Linear(in_features=300, out_features=300, bias=True)
#       (14): Linear(in_features=300, out_features=300, bias=True)
#       (15): Linear(in_features=300, out_features=300, bias=True)
#       (16): Linear(in_features=300, out_features=300, bias=True)
#       (17): Linear(in_features=300, out_features=300, bias=True)
#       (18): Linear(in_features=300, out_features=300, bias=True)
#       (19): Linear(in_features=300, out_features=300, bias=True)
#       (20): Linear(in_features=300, out_features=300, bias=True)
#       (21): Linear(in_features=300, out_features=300, bias=True)
#       (22): Linear(in_features=300, out_features=300, bias=True)
#       (23): Linear(in_features=300, out_features=300, bias=True)
#       (24): Linear(in_features=300, out_features=300, bias=True)
#       (25): Linear(in_features=300, out_features=300, bias=True)
#       (26): Linear(in_features=300, out_features=300, bias=True)
#       (27): Linear(in_features=300, out_features=300, bias=True)
#       (28): Linear(in_features=300, out_features=300, bias=True)
#       (29): Linear(in_features=300, out_features=300, bias=True)
#       (30): Linear(in_features=300, out_features=300, bias=True)
#       (31): Linear(in_features=300, out_features=300, bias=True)
#       (32): Linear(in_features=300, out_features=300, bias=True)
#       (33): Linear(in_features=300, out_features=300, bias=True)
#       (34): Linear(in_features=300, out_features=300, bias=True)
#       (35): Linear(in_features=300, out_features=300, bias=True)
#       (36): Linear(in_features=300, out_features=300, bias=True)
#       (37): Linear(in_features=300, out_features=300, bias=True)
#       (38): Linear(in_features=300, out_features=300, bias=True)
#       (39): Linear(in_features=300, out_features=300, bias=True)
#       (40): Linear(in_features=300, out_features=300, bias=True)
#       (41): Linear(in_features=300, out_features=300, bias=True)
#       (42): Linear(in_features=300, out_features=300, bias=True)
#       (43): Linear(in_features=300, out_features=300, bias=True)
#       (44): Linear(in_features=300, out_features=300, bias=True)
#       (45): Linear(in_features=300, out_features=300, bias=True)
#       (46): Linear(in_features=300, out_features=300, bias=True)
#       (47): Linear(in_features=300, out_features=300, bias=True)
#       (48): Linear(in_features=300, out_features=300, bias=True)
#       (49): Linear(in_features=300, out_features=300, bias=True)
#       (50): Linear(in_features=300, out_features=300, bias=True)
#       (51): Linear(in_features=300, out_features=300, bias=True)
#       (52): Linear(in_features=300, out_features=300, bias=True)
#       (53): Linear(in_features=300, out_features=300, bias=True)
#       (54): Linear(in_features=300, out_features=300, bias=True)
#       (55): Linear(in_features=300, out_features=300, bias=True)
#       (56): Linear(in_features=300, out_features=300, bias=True)
#       (57): Linear(in_features=300, out_features=300, bias=True)
#       (58): Linear(in_features=300, out_features=300, bias=True)
#       (59): Linear(in_features=300, out_features=300, bias=True)
#       (60): Linear(in_features=300, out_features=300, bias=True)
#       (61): Linear(in_features=300, out_features=300, bias=True)
#       (62): Linear(in_features=300, out_features=300, bias=True)
#       (63): Linear(in_features=300, out_features=300, bias=True)
#     )
#     (2): ModuleList(
#       (0): Linear(in_features=300, out_features=300, bias=True)
#       (1): Linear(in_features=300, out_features=300, bias=True)
#       (2): Linear(in_features=300, out_features=300, bias=True)
#       (3): Linear(in_features=300, out_features=300, bias=True)
#       (4): Linear(in_features=300, out_features=300, bias=True)
#       (5): Linear(in_features=300, out_features=300, bias=True)
#       (6): Linear(in_features=300, out_features=300, bias=True)
#       (7): Linear(in_features=300, out_features=300, bias=True)
#       (8): Linear(in_features=300, out_features=300, bias=True)
#       (9): Linear(in_features=300, out_features=300, bias=True)
#       (10): Linear(in_features=300, out_features=300, bias=True)
#       (11): Linear(in_features=300, out_features=300, bias=True)
#       (12): Linear(in_features=300, out_features=300, bias=True)
#       (13): Linear(in_features=300, out_features=300, bias=True)
#       (14): Linear(in_features=300, out_features=300, bias=True)
#       (15): Linear(in_features=300, out_features=300, bias=True)
#       (16): Linear(in_features=300, out_features=300, bias=True)
#       (17): Linear(in_features=300, out_features=300, bias=True)
#       (18): Linear(in_features=300, out_features=300, bias=True)
#       (19): Linear(in_features=300, out_features=300, bias=True)
#       (20): Linear(in_features=300, out_features=300, bias=True)
#       (21): Linear(in_features=300, out_features=300, bias=True)
#       (22): Linear(in_features=300, out_features=300, bias=True)
#       (23): Linear(in_features=300, out_features=300, bias=True)
#       (24): Linear(in_features=300, out_features=300, bias=True)
#       (25): Linear(in_features=300, out_features=300, bias=True)
#       (26): Linear(in_features=300, out_features=300, bias=True)
#       (27): Linear(in_features=300, out_features=300, bias=True)
#       (28): Linear(in_features=300, out_features=300, bias=True)
#       (29): Linear(in_features=300, out_features=300, bias=True)
#       (30): Linear(in_features=300, out_features=300, bias=True)
#       (31): Linear(in_features=300, out_features=300, bias=True)
#       (32): Linear(in_features=300, out_features=300, bias=True)
#       (33): Linear(in_features=300, out_features=300, bias=True)
#       (34): Linear(in_features=300, out_features=300, bias=True)
#       (35): Linear(in_features=300, out_features=300, bias=True)
#       (36): Linear(in_features=300, out_features=300, bias=True)
#       (37): Linear(in_features=300, out_features=300, bias=True)
#       (38): Linear(in_features=300, out_features=300, bias=True)
#       (39): Linear(in_features=300, out_features=300, bias=True)
#       (40): Linear(in_features=300, out_features=300, bias=True)
#       (41): Linear(in_features=300, out_features=300, bias=True)
#       (42): Linear(in_features=300, out_features=300, bias=True)
#       (43): Linear(in_features=300, out_features=300, bias=True)
#       (44): Linear(in_features=300, out_features=300, bias=True)
#       (45): Linear(in_features=300, out_features=300, bias=True)
#       (46): Linear(in_features=300, out_features=300, bias=True)
#       (47): Linear(in_features=300, out_features=300, bias=True)
#       (48): Linear(in_features=300, out_features=300, bias=True)
#       (49): Linear(in_features=300, out_features=300, bias=True)
#       (50): Linear(in_features=300, out_features=300, bias=True)
#       (51): Linear(in_features=300, out_features=300, bias=True)
#       (52): Linear(in_features=300, out_features=300, bias=True)
#       (53): Linear(in_features=300, out_features=300, bias=True)
#       (54): Linear(in_features=300, out_features=300, bias=True)
#       (55): Linear(in_features=300, out_features=300, bias=True)
#       (56): Linear(in_features=300, out_features=300, bias=True)
#       (57): Linear(in_features=300, out_features=300, bias=True)
#       (58): Linear(in_features=300, out_features=300, bias=True)
#       (59): Linear(in_features=300, out_features=300, bias=True)
#       (60): Linear(in_features=300, out_features=300, bias=True)
#       (61): Linear(in_features=300, out_features=300, bias=True)
#       (62): Linear(in_features=300, out_features=300, bias=True)
#       (63): Linear(in_features=300, out_features=300, bias=True)
#     )
#     (3): ModuleList(
#       (0): Linear(in_features=300, out_features=300, bias=True)
#       (1): Linear(in_features=300, out_features=300, bias=True)
#       (2): Linear(in_features=300, out_features=300, bias=True)
#       (3): Linear(in_features=300, out_features=300, bias=True)
#       (4): Linear(in_features=300, out_features=300, bias=True)
#       (5): Linear(in_features=300, out_features=300, bias=True)
#       (6): Linear(in_features=300, out_features=300, bias=True)
#       (7): Linear(in_features=300, out_features=300, bias=True)
#       (8): Linear(in_features=300, out_features=300, bias=True)
#       (9): Linear(in_features=300, out_features=300, bias=True)
#       (10): Linear(in_features=300, out_features=300, bias=True)
#       (11): Linear(in_features=300, out_features=300, bias=True)
#       (12): Linear(in_features=300, out_features=300, bias=True)
#       (13): Linear(in_features=300, out_features=300, bias=True)
#       (14): Linear(in_features=300, out_features=300, bias=True)
#       (15): Linear(in_features=300, out_features=300, bias=True)
#       (16): Linear(in_features=300, out_features=300, bias=True)
#       (17): Linear(in_features=300, out_features=300, bias=True)
#       (18): Linear(in_features=300, out_features=300, bias=True)
#       (19): Linear(in_features=300, out_features=300, bias=True)
#       (20): Linear(in_features=300, out_features=300, bias=True)
#       (21): Linear(in_features=300, out_features=300, bias=True)
#       (22): Linear(in_features=300, out_features=300, bias=True)
#       (23): Linear(in_features=300, out_features=300, bias=True)
#       (24): Linear(in_features=300, out_features=300, bias=True)
#       (25): Linear(in_features=300, out_features=300, bias=True)
#       (26): Linear(in_features=300, out_features=300, bias=True)
#       (27): Linear(in_features=300, out_features=300, bias=True)
#       (28): Linear(in_features=300, out_features=300, bias=True)
#       (29): Linear(in_features=300, out_features=300, bias=True)
#       (30): Linear(in_features=300, out_features=300, bias=True)
#       (31): Linear(in_features=300, out_features=300, bias=True)
#       (32): Linear(in_features=300, out_features=300, bias=True)
#       (33): Linear(in_features=300, out_features=300, bias=True)
#       (34): Linear(in_features=300, out_features=300, bias=True)
#       (35): Linear(in_features=300, out_features=300, bias=True)
#       (36): Linear(in_features=300, out_features=300, bias=True)
#       (37): Linear(in_features=300, out_features=300, bias=True)
#       (38): Linear(in_features=300, out_features=300, bias=True)
#       (39): Linear(in_features=300, out_features=300, bias=True)
#       (40): Linear(in_features=300, out_features=300, bias=True)
#       (41): Linear(in_features=300, out_features=300, bias=True)
#       (42): Linear(in_features=300, out_features=300, bias=True)
#       (43): Linear(in_features=300, out_features=300, bias=True)
#       (44): Linear(in_features=300, out_features=300, bias=True)
#       (45): Linear(in_features=300, out_features=300, bias=True)
#       (46): Linear(in_features=300, out_features=300, bias=True)
#       (47): Linear(in_features=300, out_features=300, bias=True)
#       (48): Linear(in_features=300, out_features=300, bias=True)
#       (49): Linear(in_features=300, out_features=300, bias=True)
#       (50): Linear(in_features=300, out_features=300, bias=True)
#       (51): Linear(in_features=300, out_features=300, bias=True)
#       (52): Linear(in_features=300, out_features=300, bias=True)
#       (53): Linear(in_features=300, out_features=300, bias=True)
#       (54): Linear(in_features=300, out_features=300, bias=True)
#       (55): Linear(in_features=300, out_features=300, bias=True)
#       (56): Linear(in_features=300, out_features=300, bias=True)
#       (57): Linear(in_features=300, out_features=300, bias=True)
#       (58): Linear(in_features=300, out_features=300, bias=True)
#       (59): Linear(in_features=300, out_features=300, bias=True)
#       (60): Linear(in_features=300, out_features=300, bias=True)
#       (61): Linear(in_features=300, out_features=300, bias=True)
#       (62): Linear(in_features=300, out_features=300, bias=True)
#       (63): Linear(in_features=300, out_features=300, bias=True)
#     )
#   )
#   (2): ModuleList(
#     (0): ModuleList(
#       (0): Linear(in_features=300, out_features=300, bias=True)
#       (1): Linear(in_features=300, out_features=300, bias=True)
#       (2): Linear(in_features=300, out_features=300, bias=True)
#       (3): Linear(in_features=300, out_features=300, bias=True)
#       (4): Linear(in_features=300, out_features=300, bias=True)
#       (5): Linear(in_features=300, out_features=300, bias=True)
#       (6): Linear(in_features=300, out_features=300, bias=True)
#       (7): Linear(in_features=300, out_features=300, bias=True)
#       (8): Linear(in_features=300, out_features=300, bias=True)
#       (9): Linear(in_features=300, out_features=300, bias=True)
#       (10): Linear(in_features=300, out_features=300, bias=True)
#       (11): Linear(in_features=300, out_features=300, bias=True)
#       (12): Linear(in_features=300, out_features=300, bias=True)
#       (13): Linear(in_features=300, out_features=300, bias=True)
#       (14): Linear(in_features=300, out_features=300, bias=True)
#       (15): Linear(in_features=300, out_features=300, bias=True)
#       (16): Linear(in_features=300, out_features=300, bias=True)
#       (17): Linear(in_features=300, out_features=300, bias=True)
#       (18): Linear(in_features=300, out_features=300, bias=True)
#       (19): Linear(in_features=300, out_features=300, bias=True)
#       (20): Linear(in_features=300, out_features=300, bias=True)
#       (21): Linear(in_features=300, out_features=300, bias=True)
#       (22): Linear(in_features=300, out_features=300, bias=True)
#       (23): Linear(in_features=300, out_features=300, bias=True)
#       (24): Linear(in_features=300, out_features=300, bias=True)
#       (25): Linear(in_features=300, out_features=300, bias=True)
#       (26): Linear(in_features=300, out_features=300, bias=True)
#       (27): Linear(in_features=300, out_features=300, bias=True)
#       (28): Linear(in_features=300, out_features=300, bias=True)
#       (29): Linear(in_features=300, out_features=300, bias=True)
#       (30): Linear(in_features=300, out_features=300, bias=True)
#       (31): Linear(in_features=300, out_features=300, bias=True)
#       (32): Linear(in_features=300, out_features=300, bias=True)
#       (33): Linear(in_features=300, out_features=300, bias=True)
#       (34): Linear(in_features=300, out_features=300, bias=True)
#       (35): Linear(in_features=300, out_features=300, bias=True)
#       (36): Linear(in_features=300, out_features=300, bias=True)
#       (37): Linear(in_features=300, out_features=300, bias=True)
#       (38): Linear(in_features=300, out_features=300, bias=True)
#       (39): Linear(in_features=300, out_features=300, bias=True)
#       (40): Linear(in_features=300, out_features=300, bias=True)
#       (41): Linear(in_features=300, out_features=300, bias=True)
#       (42): Linear(in_features=300, out_features=300, bias=True)
#       (43): Linear(in_features=300, out_features=300, bias=True)
#       (44): Linear(in_features=300, out_features=300, bias=True)
#       (45): Linear(in_features=300, out_features=300, bias=True)
#       (46): Linear(in_features=300, out_features=300, bias=True)
#       (47): Linear(in_features=300, out_features=300, bias=True)
#       (48): Linear(in_features=300, out_features=300, bias=True)
#       (49): Linear(in_features=300, out_features=300, bias=True)
#       (50): Linear(in_features=300, out_features=300, bias=True)
#       (51): Linear(in_features=300, out_features=300, bias=True)
#       (52): Linear(in_features=300, out_features=300, bias=True)
#       (53): Linear(in_features=300, out_features=300, bias=True)
#       (54): Linear(in_features=300, out_features=300, bias=True)
#       (55): Linear(in_features=300, out_features=300, bias=True)
#       (56): Linear(in_features=300, out_features=300, bias=True)
#       (57): Linear(in_features=300, out_features=300, bias=True)
# ...
# Batch Loss: 68.03260803222656; Batch Time: 5.871965408325195s;
# 237it [23:38,  5.65s/it]
# Batch Loss: 68.02984619140625; Batch Time: 5.142605304718018s;
# 238it [23:43,  5.50s/it]
# Batch Loss: 68.02896881103516; Batch Time: 6.204909801483154s;
# 239it [23:50,  5.71s/it]
# Batch Loss: 68.02670288085938; Batch Time: 6.604967832565308s;
# 240it [23:56,  5.98s/it]
# Batch Loss: 68.02474212646484; Batch Time: 6.328916072845459s;
# 241it [24:03,  6.09s/it]
# Batch Loss: 68.0234603881836; Batch Time: 4.563059329986572s;
# 242it [24:07,  5.63s/it]
# Batch Loss: 68.02151489257812; Batch Time: 5.688363790512085s;
# 243it [24:13,  5.65s/it]
